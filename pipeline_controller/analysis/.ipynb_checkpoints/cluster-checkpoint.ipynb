# %%
import psycopg2
import pandas as pd
import numpy as np

# %%
# Definir a URL do banco de dados
DATABASE_URL = "postgresql://postgres:super#@localhost:5432/ml_social_db"

# Conectar ao banco de dados
conn = psycopg2.connect(DATABASE_URL)
cursor = conn.cursor()

# %%
# Definir o ID para filtragem (hardcoded)
id_filtrado = 'a1789446-9083-4fdc-9a13-44568269c6ce' 

# Buscar embeddings e textos da tabela
cursor.execute("""
    SELECT embeddings, content FROM content 
    WHERE id = %s;
""", (id_filtrado,))
data = cursor.fetchall()

# Fechar conexão com o banco
cursor.close()
conn.close()

# %%
# Converter os embeddings (BYTEA para array NumPy)
embeddings = np.array([np.frombuffer(row[0], dtype=np.float32) for row in data])
textos_originais = [row[1] for row in data]

# Verificar a dimensão dos embeddings
print(f"Shape dos embeddings: {embeddings.shape}")  # Deve ser (n_samples, n_features)
# Out:
# Shape dos embeddings: (1137, 3072)

# %%
import faiss
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# Função para calcular o Gap Statistic
def gap_statistic(embeddings, k_min=2, k_max=10, n_refs=10):
    gaps = []
    ks = list(range(k_min, k_max + 1))

    # Verifica se há embeddings suficientes para evitar erro
    if embeddings.shape[0] < k_max:
        k_max = embeddings.shape[0] - 1

    # Obter valores mínimo e máximo para cada dimensão
    min_vals = embeddings.min(axis=0)
    max_vals = embeddings.max(axis=0)

    # Criar distribuições de referência (dados aleatórios)
    random_references = np.array([
        np.random.uniform(low=min_vals, high=max_vals, size=embeddings.shape)
        for _ in range(n_refs)
    ])

    for k in ks:
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        kmeans.fit(embeddings)
        disp = np.mean(np.min(cdist(embeddings, kmeans.cluster_centers_, "cosine"), axis=1))

        ref_disps = []
        for j in range(n_refs):
            kmeans.fit(random_references[j])  # Treinar nos dados aleatórios
            ref_disp = np.mean(np.min(cdist(random_references[j], kmeans.cluster_centers_, "cosine"), axis=1))
            ref_disps.append(ref_disp)

        gap = np.log(np.mean(ref_disps)) - np.log(disp)
        gaps.append(gap)

    best_k = ks[np.argmax(gaps)]
    
    return best_k, ks, gaps

# Função para encontrar o melhor k usando apenas o Gap Statistic
def encontrar_melhor_k(embeddings, k_min=2, k_max=20):
    # Garante que os embeddings sejam um array numpy
    embeddings = np.array(embeddings)

    if embeddings.shape[0] < k_min + 1:
        raise ValueError("Número insuficiente de embeddings para clusterização.")

    # 1. Gap Statistic
    best_k, ks_gap, gaps = gap_statistic(embeddings, k_min, k_max)

    # 2. Criar gráfico do Gap Statistic
    plt.figure(figsize=(6, 4))
    plt.plot(ks_gap, gaps, marker="o", linestyle="-", label="Gap Statistic")
    plt.axvline(best_k, color="r", linestyle="--", label=f"Melhor k pelo Gap = {best_k}")
    plt.xlabel("Número de Clusters (k)")
    plt.ylabel("Gap Statistic")
    plt.title("Gap Statistic para escolha do número de clusters")
    plt.legend()
    plt.show()

    print(f"🔹 Melhor número de clusters encontrado: {best_k} (Gap Statistic)")

    return best_k

# Verifica se `embeddings` está disponível
if 'embeddings' not in locals():
    raise ValueError("Variável `embeddings` não foi definida.")

best_k = encontrar_melhor_k(embeddings)

# Ajuste de `niter` e `nredo` dinamicamente baseado no tamanho dos dados
num_dados = embeddings.shape[0]
niter = 100 if num_dados < 5000 else 200  
nredo = 5 if num_dados < 5000 else 10  

# Criar clusters com FAISS usando o melhor k encontrado
kmeans = faiss.Kmeans(d=embeddings.shape[1], k=best_k, niter=niter, nredo=nredo, spherical=True)
kmeans.train(embeddings)

# Atribuir clusters
_, labels = kmeans.index.search(embeddings, 1)
labels = labels.flatten()

# Criar DataFrame para análise dos clusters
df = pd.DataFrame({"text": textos_originais, "cluster": labels})

# Exibir exemplos de cada cluster
for cluster_id in sorted(df["cluster"].unique()):
    print(f"\n🔹 **Exemplos do Cluster {cluster_id}:**")
    
    exemplos = df[df["cluster"] == cluster_id]["text"]
    if exemplos.shape[0] < 10:
        exemplos = exemplos.sample(exemplos.shape[0], random_state=42)  # Evita erro se houver poucos exemplos
    else:
        exemplos = exemplos.sample(10, random_state=42)  # Pegando 10 exemplos
    
    for idx, texto in enumerate(exemplos, start=1):
        print(f"{idx}. {texto}")
# Out:
# 🔹 Melhor número de clusters encontrado: 20 (Gap Statistic)
#
# 🔹 **Exemplos do Cluster 0:**
# 1. Vc fazendo esse videos ta me deixando cada vez mais ansioso pra esse console.
# 2. Finalmente podemos rodar tetris em 720p
# 3. FALOU O ESPECIALISTA EM GAMES
# 4. Gostava da época quando os videogames eram comparados por bits  😅😅
# 5. <a href="https://www.youtube.com/watch?v=31BvwbyZG-4&amp;t=144">2:24</a> parabens nintendo, vc inventou uma feature que smartphones tem desde 2012
# 6. Ei Coelho, grava um vídeo contando como a PlayStation surgiu a partir de uma traição da Nintendo. Eu gostaria de um quadro contando a história de cada console da Big N, seria incrível 😊
# 7. parabéns dig, achei interessantíssimo o jeito q o console vai trabalhar e fiquei bem feliz mesmo
# 8. Tou tão ansioso que acordei pensando nesse videogame e vc lançou um vídeo dele, coisa boa
# 9. Tem um video gringo de um gamedev explicando minunciosamente porque esse mario kart é tão impressionante, como ele faz um uso de iluminação volumetrica que o switch 1 não conseguiria e outros detalhes assim. Não achei essa pista em especifico bonita, nem os personagens, especialmente o DK amassado, mas da para ver que houve uma evolução significativa
# 10. Boa tarde, eu tenho uma duvida que não tem nada a ver com a publicação, se poderem me responder eu vou ficar agradecida. Porque quando fala o nome do Xenoblade eles leem com &quot;Z&quot; em vez de &quot;X&quot;? Muito obrigada a todos!!!
#
# 🔹 **Exemplos do Cluster 1:**
# 1. Rdr2 é obrigação no switch!<br><br>GTA VI, se vier é lucro
# 2. resumindo, vai ser possível qualquer porte para o nintendo switch, isso inclui até gta 6  poderá ser possível. Resta esperar saber se as desenvolvedoras vão conseguir usar essa tecnolgia na prática.
# 3. Nintendo switch 2 = Nintendo switch PRO
# 4. CARA TEM QUE TER PHASMOPHOBIA PARA O NINTENDO SWITCH 2
# 5. Faz um vídeo dos possíveis jogos de terror que pode chegar pro Nintendo switch 2
# 6. Queira pelo menos o GTA5 no switch
# 7. Pq cara so de ter um resident Evil remakes e 7 8 e possível 9 <br>Nesse SWITCH 2 nem que seja 1080p pra mim particularmente ta lindo
# 4. Essa animação de apresentação tá bonito demais. <br><br>Só espero que esse sistema de prender os joycons não seja tão frágil que caia o controle enquanto vc está no modo portátil, aquele conector lateral me parece bem frágil se o joycon soltar numa situação dessas
# 5. <a href="https://www.youtube.com/watch?v=NIlJc_zzUIw&amp;t=514">8:34</a> possam os cartuchos não suportar do Switch 1 pro 2 bem por causa do Mig Switch que tão colocando, a segurança deve ser bem aprimorada
# 6. 😨 Coisa magnética sai fácil , eu não confio 🎮
# 7. <a href="https://www.youtube.com/watch?v=rAPjNqGFgQk&amp;t=45">00:45</a> eu tenho um controle edição especial do splatoon que está dando esse problema.<br>Se eu mandar pra eles arrumarem vai voltar o mesmo controle ou eles apenas substituem ?😅
# 8. esses negócio do defeito é tão verdade que todo videogame de cada geração teve um defeito de fábrica:<br>ps1: leitor de disco<br>n64: analogico com data de validade <br>ps2: super aquecimento e leitor problemático tbm<br>ps3: luz amarela da morte<br>xbox 360: 3 luzes vermelhas<br>switch: drift no joy con<br>ps4: HDMI<br>ds e 3ds: era comum nos modelos primeiros modelos a tela superior parar de funcionar <br><br>e mtos outros q não citei, mad fique a vontade para adicionar qualquer um que você lembrar
# 9. Tô com medo desses Joy cons tiver problemas com drift de novo 💀💀💀💀 aí vai ser fuck, Nintendo
# 10. Quem teve ps2 sabe que aqueles controles piratas que você comprava na feirinha de quinta sempre dava drift no analógico dele toda vez que cê forçava
#
# 🔹 **Exemplos do Cluster 9:**
# 1. Tem um dev aqui no youtube que estava trabalhando em um jogo para Switch 1 mas eles decidiram fazer para switch 2, e ele fez um vídeo similar (youtuber Sungrand Studios). No começo ele fala que tem detalhes que não pode dar por causa de NDAs, o que indica que ele pode estar já trabalhando com kits de desenvolvimento do novo console. Mas ele deu detalhes do poder do Switch usando só os detalhes do jogo. Uma coisa importante é que dá para inferir poder gráfico e memória de GPU a partir da qualidade das texturas, da distância de renderização de sombras e da oclusão volumétrica de objetos distantes como nuvens, por exemplo. Parece que o Switch 2 vai ser bem poderoso mesmo! Não um PS5, mas vai ser muito bom
# 2. Imagina você ter em mãos um portátil mais barato que o Steam Deck, com duração de bateria muito maior que a do Steam Deck e potencial gráfico na dock comparável a um Xbox Series S? Se isso for verdade, é muito melhor do que eu imaginava. Não precisa melhorar nada em potencial. Essa geração atual mal mostrou grandes diferenças gráficas da anterior mesmo. É um absurdo de poder de processamento usado apenas para resolução e FPS, duas coisas que o Switch 2 pode conseguir com muito menos poder de hardware através do DLSS.
# 3. Finalmente canais começando a falar dobre isso.<br>Vejo muita gente reclamando que o switch 2 vai ter um poder de ps4 pro e falam que isso é defasado porém esquecem que os jogos da atual geração tbm rodariam na geração passada ou seja o switch 2 não está defasado em nada isso pq ainda não falamos do dlss e a nova arquitetura do switch 2.<br>Cara se o switch 2 vir com todo aquele rumor de poder gráfico não a desculpa nenhuma de não ter jogos atuais feitos lançados pra ele.
# 4. O hardware deve ser obviamente mais potente mas a sensação é que estamos vendo um switch XL.
# 5. De acordo com o q foi estudado sobre o vazamento no modo portátil el tera 2 teraflops de potência um pouco superior ao Ps4 normal e na doca 3,6 quase um Ps4 pro, terá Ray-tracing, usaria placa invídia da série e rtx20 terá núcleos dedicados pra inteligência artificial q vai tbm otimizar os gráficos,12 gb de ram ddrs,  eu não sei os detalhes de tudo isso então eu recomendaria o short do canal Autoridade Tech onde ele fala as especificações mais direto ao ponto
# 6. Como engenheiro e desenvolver de software, posso afirmar que esse foi um dos melhores vídeos que vi sobre o Switch 2 (e eu vi vídeos da gringa). O Switch 2 tem potencial para rodar qualquer jogo dessa geração. Eu inclusive digo que irá rodar GTA VI, mesmo que em configuração bem mais limitada.
# 7. e qual seria as especificaçoes tecnicas dele ? teve upgrade significativo comparado aos outros consoles , ou continua sendo abaixo nos comparativos ??
# 8. Ao que compreendi, até o momento, é que teremos duas saídas USB-C, uma abaixo e outra acima próxima do cartucho, serão 256gb de memória interna, HDMI 2.1 (4K compatible), teremos duas bands de memória LPDDR5X de 6gb (Ao lado do SoC da Nvidia) e que, supostamente, não são 8 nm e sim 5 nm, o que vai auxiliar com a questão de uso de energia desse sistema mais robusto quando usarmos como portátil. Até porque em docked mode o consumo de bateria é irrelevante. De qualquer maneira, é um pulo considerável e, provavelmente, a maneira correta de fazer um portátil que de quebra ainda é híbrido. Veremos.
# 9. Os jogos da Nintendo não tem um gráfico fixo no do console, então se colocar ele em um console mais potente, como será o switch 2, os gráficos já irão ficar melhor por si só
# 10. Switch rodava 1080p uma grande quantidade de jogos 😅<br><br>Nier Automata por exemplo roda a 1080p no switch e  no ps4 roda a 900p.<br><br>Reduziram algumas texturas escondidas e fixaram o FPS em 30.<br><br>Isso na Dock.
#
# 🔹 **Exemplos do Cluster 10:**
# 1. Acho difícil eles investirem muito no mouse, sem sombra de dúvidas haverá um Switch 2 Lite, foi um dos modelos mais vendidos do 1, não teria porque não repetir a fórmula, e como ficariam esse modelo com as &quot;funções exclusivas&quot;? no 1 as funções incompatíveis com o Lite sempre foram muito tímidas e pra muitos irrelevantes já pq eles não queriam dividir a própria base de consumidores, então essa função de mouse vai ser só uma coisinha extra muito bem vinda, mas não essencial pra experiência, por exemplo Metroid Prime 4 já vai ser apresentado usando, mas sendo possível jogar pelos analógicos também
# 2. O Legion Go tá aí, mas com certeza a pegada e a precisão do Joy Con 2 será melhor.
# 3. O mouse é o diferencial Edu! Pode ter muita coisa boa vindo disso
# 4. Espero q o Switch 2 além de usar o Joycon 2 como mouse, possa usar tbm mouses de terceiros<br>Como os bluetooths por exemplo<br>Ai seria MTO foda
# 5. cara fone bluetooth pra jogar a grande maioria vai ter a traso, menos os modelos bem (bem mais caros), então ter um p3 é o minimo nesse cenario, ainda bem que a nitendo botou
# 6. Ou vai ser um &quot;air-mouse&quot; ou virá acompanhando um &quot;mousepad&quot; que prende na perna.
# 7. e não é só um mouse, são dois, dois joycons que podem ser usados como mouse ao mesmo tempo, e ainda mais, podendo usar a função mouse junto om os botões, imagina algum sistema ou forma de jogar onde se usa dois mouses ao mesmo tempo.
# 8. <a href="https://www.youtube.com/watch?v=3wZhr6-CNYE&amp;t=586">9:46</a> de fato nenhuma empresa principal (Sony, Microsoft, Steam) do mercado de games fez a função mouse nos controles, POREM a Lenovo fez em seu Legion Go, então não é de fato inovação (como algo criado/inventado pela nintendo, algo que ninguém nunca tinha feito antes), mas é uma função extremamente bem vinda e pode ser que a nintendo inove mostrando uma utilização mais bem desenvolvida ou prática para uso no dia a dia.
# 9. Em <a href="https://www.youtube.com/watch?v=rAPjNqGFgQk&amp;t=339">5:39</a> passou bem rápido, mas vi a imagem de um Joy-con diferente, parece um modelo mais ergonômico,  e tbm sendo usado como mouse.
# 10. já sinto a tendinite só de ver a ergonomia desse &quot;mouse&quot;
#
# 🔹 **Exemplos do Cluster 11:**
# 1. Gente da central amoooo vocês.
# 2. Excelente quinta-feira pra você Edu
# 3. vim mais rápido que piloto de formula 1
# 4. e esses canhões de fumaça ai?
# 5. Acessível e Brasil na mesma frase não existe e nunca existiu.<br>Brasileiro tem mania de normalizar coisas ruins e aceitar tudo como se fosse super normal, sem contar os que bate palma e passa pano pra muitas coisas.<br>Ai as coisas vai piorando cada vez mais, e os banana acha que antes era bom, não era bom, só era menos ruim.<br>Infelizmente ou pagamos o absurdo cobrado ou vai procurar fazer outra coisa.
# 6. Cara, eu acho o Angelo super simpático e tal, mas sou só eu ou ele sempre parece muito mais perdido e por fora das coisas do que o Bruno e o Breno?
# 7. O Monstro está Saindo da Jaula.
# 8. Eu amo  que o oculos  faz o  rosto do  ph distorcer  kkkkkk
# 9. Que venha Massa
# 10. Mais um item na planilha do mês 😏😏😏😏
#
# 🔹 **Exemplos do Cluster 12:**
# 1. Switch 2 será mais fraco do que o steam Deck.
# 2. Pra quem duvidou do Switch 2 LCD 4K, tá aí 4K de reais 😅
# 3. Uma pena ainda não estar em full hd pra gente ver todo o garbo e elegância do Edu, e do Switch 2.
# 4. Eu me surpreenderia se o switch 2 tivesse um navegador. Mas sabemos que isso jamais existiria!
# 5. Switch 2 pode vir quebrado que eu compro do mesmo jeiro
# 6. Não renovei meu switch on-line na esperança que eles façam algo descente no switch 2. Só pagava pq precisava pra rodar alguns jogos que precisavam do passe pra jogar.
# 7. Switch 2 é moderno por fora e antigo por dentro hahaha
# 8. Na minha conta, é 7.2x o switch portátil, e 7.8x o switch no dock.
# 9. O Switch 2 está demais, muito lindo!
# 10. switch online é paia demais.
#
# 🔹 **Exemplos do Cluster 13:**
# 1. <a href="https://www.youtube.com/watch?v=3sazf2jyKZo&amp;t=130">2:10</a> Eu sei que é boa, e quase nem parece 8 bits. XD
# 2. Wow I used an Ai voice translator on this video &amp; omg it worked! Your voice in Eng by the Ai is on point &amp; scary at the same time. There was no errors.
# 3. São os 12 primeiros segundos mais fortes já vistos em um vídeo do PH.<br>E mesmo assim não serão fortes o suficiente para a implacável pergunta:   &quot;Tá, mas qual é a data e preço, PH ?&quot;
# 4. <a href="https://www.youtube.com/watch?v=tt9whasLXIY&amp;t=315">5:15</a> O MK do Swtch parece The Sims
# 5. <a href="https://www.youtube.com/watch?v=YpWQGtUfVOA&amp;t=218">3:38</a> então pra vc maior é melhor 🤭
# 6. <a href="https://www.youtube.com/watch?v=31BvwbyZG-4&amp;t
# 7. Esse novo Mário Kart ta com uma carinha que vai ter um modo exclusivo alá Cruis&#39;n USA, só que Cruis&#39;n Mario World, onde as pistas nao tem voltas, são mais longas e vão ligando de uma região à outra. E assim o player vai acompanhando a mudança de ambientação, como vegetação, geografia, clima etc 😮
# 8. <a href="https://www.youtube.com/watch?v=NIlJc_zzUIw&amp;t=380">6:20</a> Ninguém fala, mais o Modelo que mudou muito também foi o do Mario e do Luigi, eles estão com o mesmo estilo do Mario Wonder é só comparar os dois modelos do Mario que a diferença é perceptível.  Sem contar que este modelo de Kart parece um pouco diferente do que estamos abtuados a ver em MK8. Sem contar que no minuto <a href="https://www.youtube.com/watch?v=NIlJc_zzUIw&amp;t=383">6:23</a> o boost no chão esta diferente do MK8 e MK8 DLX.
# 9. Lembor de mario e wario no snes que tinha que usar o mouse, era de puzzle, muito bom o game na pegada de mario vs donkey kong do gba
# 10. 💁🏻‍♂️Espero q lancem um novo Mega Man no estilo do Nintendinho🎮🤩😍😎🍷🗿
#
# 🔹 **Exemplos do Cluster 17:**
# 1. Switch 2, só 6 meses depois, no mínimo, porque early adopter só se ferra. E sim, tem que sair por volta de 3000. E os games tem que custar no máximo os 300 reais que custam agora os do Switch original (e esses tem que ter uma boa queda de preço).
# 2. Legal que vai lançar o switch 2. Dito isso, vou comprar o switch lite. Preço de lançamento não dá não, e ainda tem chances de vir com algum problema de primeira leva de console, coisa que quase sempre tem.
# 3. Será que a Nintendo vai abaixar o preço do OLED pra 299 e tirar o V2 de linha?
# 4. Se a Nintendo demorar mais uns 15 dias pra anunciar esse negócio, vão tar vendendo uma versão &quot;original&quot; dele na 25 de março 😂
# 5. A resposta é óbvia: como o Switch 2 vai rodar praticamente tudo do 1, o negócio é esperar uns 2 anos para ver se o Switch 2 não vem com defeito de fabricação nos joy-con ou em outra parte, daí compra.
# 6. Switch 2 &quot;POSSIVELMENTE&quot; estará na média dos 4k...<br><br>Switch 1 FAZ TODO SENTIDO NÃO CAIR DE PREÇO... pois, só pelo simples fato de o Switch 2 ser retrocompatível, o Switch 1 ainda vai bombar de vendas.
# 7. Um dos comentaristas da Bloomberg afirmou que : se o preço do Nintendo switch 2 for 400 ou menos eles irão anunciar em abril se for mais do que 400 não anunciarão! Na época o preço do 3ds não caiu 100 doletas mas 80!
# 8. tenho meu questionario rapido:<br><br>1- vc tem um switch? <br>2- vc tem os possíveis R$3,500+ que isso vai chegar aqui pra pegar o switch 2?<br>3- vc vai  pagar os 450/400 reais que os jogos de switch 2 vao custar ou vai chorar igual vc ja chora pra pagar 250+ no switch atual? ($70)<br><br>se respondeu não pra pelo menos 2 dessas, pega o switch cara, 1800 novo, pra vc que n quer gastar, pode meter o chip (que nao vai ter no 2, entao se vc chora em pagar 250+ reais em jogo de switch, imagina os 400 do switch 2)  fora que vai ter quer esperar 1 ano de switch 2 pra começarem as promoçoes relevantes de preço do switch 2 e finalmente matar a vontade de jogar switch 1 e 2 com a retrocompatibilidade
# 9. Eu fico contente de imaginar que possivelmente o Switch 2 rodará de maneira bem satisfatória jogos AAA, isso significa que o apoio vai ser ainda maior dado que o trabalho de port vai ser bem menor. <br><br>Curioso mesmo eu estou com a retrocompatibilidade, se eles pretendem de alguma forma otimizar loadings ou estabilizar FPS nos exclusivos que tiveram gargalos com isso no hardware do Switch 1<br><br>Unica tela de loading que eu gosto e apoio que demore é a Samus no elevador em Metroid Dread kkkkkk
# 10. Eu to animado pra poder melhorar os gráficos do meu Dead By Daylight, acostumei no PS5 agora não consigo mais jogar no Switch :(

# %%
import faiss
k = 20 # Definir número de clusters
kmeans = faiss.Kmeans(d=embeddings.shape[1], k=k, niter=300, nredo=10, spherical=True)

# Treinar modelo
kmeans.train(embeddings)

# Atribuir clusters
_, labels = kmeans.index.search(embeddings, 1)
labels = labels.flatten()

# Criar DataFrame para analisar os clusters
df = pd.DataFrame({"text": textos_originais, "cluster": labels})

# Exibir exemplos de cada cluster
for cluster_id in sorted(df["cluster"].unique()):
    print(f"\n🔹 **Exemplos do Cluster {cluster_id}:**")
    exemplos = df[df["cluster"] == cluster_id]["text"].sample(10, random_state=42)  # Pegando 5 exemplos
    for idx, texto in enumerate(exemplos, start=1):
        print(f"{idx}. {texto}")
# Out:
# 🔹 **Exemplos do Cluster 0:**
# 1. Vc fazendo esse videos ta me deixando cada vez mais ansioso pra esse console.
# 2. Finalmente podemos rodar tetris em 720p
# 3. FALOU O ESPECIALISTA EM GAMES
# 4. Gostava da época quando os videogames eram comparados por bits  😅😅
# 5. <a href="https://www.youtube.com/watch?v=31BvwbyZG-4&amp;t=144">2:24</a> parabens nintendo, vc inventou uma feature que smartphones tem desde 2012
# 6. Ei Coelho, grava um vídeo contando como a PlayStation surgiu a partir de uma traição da Nintendo. Eu gostaria de um quadro contando a história de cada console da Big N, seria incrível 😊
# 7. parabéns dig, achei interessantíssimo o jeito q o console vai trabalhar e fiquei bem feliz mesmo
# 8. Tou tão ansioso que acordei pensando nesse videogame e vc lançou um vídeo dele, coisa boa
# 9. Tem um video gringo de um gamedev explicando minunciosamente porque esse mario kart é tão impressionante, como ele faz um uso de iluminação volumetrica que o switch 1 não conseguiria e outros detalhes assim. Não achei essa pista em especifico bonita, nem os personagens, especialmente o DK amassado, mas da para ver que houve uma evolução significativa
# 10. Boa tarde, eu tenho uma duvida que não tem nada a ver com a publicação, se poderem me responder eu vou ficar agradecida. Porque quando fala o nome do Xenoblade eles leem com &quot;Z&quot; em vez de &quot;X&quot;? Muito obrigada a todos!!!
#
# 🔹 **Exemplos do Cluster 1:**
# 1. Rdr2 é obrigação no switch!<br><br>GTA VI, se vier é lucro
# 2. resumindo, vai ser possível qualquer porte para o nintendo switch, isso inclui até gta 6  poderá ser possível. Resta esperar saber se as desenvolvedoras vão conseguir usar essa tecnolgia na prática.
# 3. Nintendo switch 2 = Nintendo switch PRO
# 4. CARA TEM QUE TER PHASMOPHOBIA PARA O NINTENDO SWITCH 2
<a href="https://www.youtube.com/watch?v=31BvwbyZG-4&amp;t=342">5:42</a> presta atenção no suporte do tablet no switch 2 e imagina inverter ele de cabeça para baixo:<br>supondo que o suporte seja duro de mover como no switch oled, daria então pra ter suporte com ele virado de cabeça para baixo também
# 2. Segunda vez que mando meus joy cons pra deal, a primeira foi em 2021 (sim o drift é extremamente constante, ele sempre virá 😢) to esperando a entrega dos novos
# 3. Esse conector dos Joy con exposto na lateral do aparelho sei nao hein....
# 4. Essa animação de apresentação tá bonito demais. <br><br>Só espero que esse sistema de prender os joycons não seja tão frágil que caia o controle enquanto vc está no modo portátil, aquele conector lateral me parece bem frágil se o joycon soltar numa situação dessas
# 5. <a href="https://www.youtube.com/watch?v=NIlJc_zzUIw&amp;t=514">8:34</a> possam os cartuchos não suportar do Switch 1 pro 2 bem por causa do Mig Switch que tão colocando, a segurança deve ser bem aprimorada
# 6. 😨 Coisa magnética sai fácil , eu não confio 🎮
# 7. <a href="https://www.youtube.com/watch?v=rAPjNqGFgQk&amp;t=45">00:45</a> eu tenho um controle edição especial do splatoon que está dando esse problema.<br>Se eu mandar pra eles arrumarem vai voltar o mesmo controle ou eles apenas substituem ?😅
# 8. esses negócio do defeito é tão verdade que todo videogame de cada geração teve um defeito de fábrica:<br>ps1: leitor de disco<br>n64: analogico com data de validade <br>ps2: super aquecimento e leitor problemático tbm<br>ps3: luz amarela da morte<br>xbox 360: 3 luzes vermelhas<br>switch: drift no joy con<br>ps4: HDMI<br>ds e 3ds: era comum nos modelos primeiros modelos a tela superior parar de funcionar <br><br>e mtos outros q não citei, mad fique a vontade para adicionar qualquer um que você lembrar
# 9. Tô com medo desses Joy cons tiver problemas com drift de novo 💀💀💀💀 aí vai ser fuck, Nintendo
# 10. Quem teve ps2 sabe que aqueles controles piratas que você comprava na feirinha de quinta sempre dava drift no analógico dele toda vez que cê forçava
#
# 🔹 **Exemplos do Cluster 9:**
# 1. Tem um dev aqui no youtube que estava trabalhando em um jogo para Switch 1 mas eles decidiram fazer para switch 2, e ele fez um vídeo similar (youtuber Sungrand Studios). No começo ele fala que tem detalhes que não pode dar por causa de NDAs, o que indica que ele pode estar já trabalhando com kits de desenvolvimento do novo console. Mas ele deu detalhes do poder do Switch usando só os detalhes do jogo. Uma coisa importante é que dá para inferir poder gráfico e memória de GPU a partir da qualidade das texturas, da distância de renderização de sombras e da oclusão volumétrica de objetos distantes como nuvens, por exemplo. Parece que o Switch 2 vai ser bem poderoso mesmo! Não um PS5, mas vai ser muito bom
# 2. Imagina você ter em mãos um portátil mais barato que o Steam Deck, com duração de bateria muito maior que a do Steam Deck e potencial gráfico na dock comparável a um Xbox Series S? Se isso for verdade, é muito melhor do que eu imaginava. Não precisa melhorar nada em potencial. Essa geração atual mal mostrou grandes diferenças gráficas da anterior mesmo. É um absurdo de poder de processamento usado apenas para resolução e FPS, duas coisas que o Switch 2 pode conseguir com muito menos poder de hardware através do DLSS.
# 3. Finalmente canais começando a falar dobre isso.<br>Vejo muita gente reclamando que o switch 2 vai ter um poder de ps4 pro e falam que isso é defasado porém esquecem que os jogos da atual geração tbm rodariam na geração passada ou seja o switch 2 não está defasado em nada isso pq ainda não falamos do dlss e a nova arquitetura do switch 2.<br>Cara se o switch 2 vir com todo aquele rumor de poder gráfico não a desculpa nenhuma de não ter jogos atuais feitos lançados pra ele.
# 4. O hardware deve ser obviamente mais potente mas a sensação é que estamos vendo um switch XL.
# 5. De acordo com o q foi estudado sobre o vazamento no modo portátil el tera 2 teraflops de potência um pouco superior ao Ps4 normal e na doca 3,6 quase um Ps4 pro, terá Ray-tracing, usaria placa invídia da série e rtx20 terá núcleos dedicados pra inteligência artificial q vai tbm otimizar os gráficos,12 gb de ram ddrs,  eu não sei os detalhes de tudo isso então eu recomendaria o short do canal Autoridade Tech onde ele fala as especificações mais direto ao ponto
# 6. Como engenheiro e desenvolver de software, posso afirmar que esse foi um dos melhores vídeos que vi sobre o Switch 2 (e eu vi vídeos da gringa). O Switch 2 tem potencial para rodar qualquer jogo dessa geração. Eu inclusive digo que irá rodar GTA VI, mesmo que em configuração bem mais limitada.
# 7. e qual seria as especificaçoes tecnicas dele ? teve upgrade significativo comparado aos outros consoles , ou continua sendo abaixo nos comparativos ??
# 8. Ao que compreendi, até o momento, é que teremos duas saídas USB-C, uma abaixo e outra acima próxima do cartucho, serão 256gb de memória interna, HDMI 2.1 (4K compatible), teremos duas bands de memória LPDDR5X de 6gb (Ao lado do SoC da Nvidia) e que, supostamente, não são 8 nm e sim 5 nm, o que vai auxiliar com a questão de uso de energia desse sistema mais robusto quando usarmos como portátil. Até porque em docked mode o consumo de bateria é irrelevante. De qualquer maneira, é um pulo considerável e, provavelmente, a maneira correta de fazer um portátil que de quebra ainda é híbrido. Veremos.
# 9. Os jogos da Nintendo não tem um gráfico fixo no do console, então se colocar ele em um console mais potente, como será o switch 2, os gráficos já irão ficar melhor por si só
# 10. Switch rodava 1080p uma grande quantidade de jogos 😅<br><br>Nier Automata por exemplo roda a 1080p no switch e  no ps4 roda a 900p.<br><br>Reduziram algumas texturas escondidas e fixaram o FPS em 30.<br><br>Isso na Dock.
#
# 🔹 **Exemplos do Cluster 10:**
# 1. Acho difícil eles investirem muito no mouse, sem sombra de dúvidas haverá um Switch 2 Lite, foi um dos modelos mais vendidos do 1, não teria porque não repetir a fórmula, e como ficariam esse modelo com as &quot;funções exclusivas&quot;? no 1 as funções incompatíveis com o Lite sempre foram muito tímidas e pra muitos irrelevantes já pq eles não queriam dividir a própria base de consumidores, então essa função de mouse vai ser só uma coisinha extra muito bem vinda, mas não essencial pra experiência, por exemplo Metroid Prime 4 já vai ser apresentado usando, mas sendo possível jogar pelos analógicos também
# 2. O Legion Go tá aí, mas com certeza a pegada e a precisão do Joy Con 2 será melhor.
# 3. O mouse é o diferencial Edu! Pode ter muita coisa boa vindo disso
# 4. Espero q o Switch 2 além de usar o Joycon 2 como mouse, possa usar tbm mouses de terceiros<br>Como os bluetooths por exemplo<br>Ai seria MTO foda
# 5. cara fone bluetooth pra jogar a grande maioria vai ter a traso, menos os modelos bem (bem mais caros), então ter um p3 é o minimo nesse cenario, ainda bem que a nitendo botou
# 6. Ou vai ser um &quot;air-mouse&quot; ou virá acompanhando um &quot;mousepad&quot; que prende na perna.
# 7. e não é só um mouse, são dois, dois joycons que podem ser usados como mouse ao mesmo tempo, e ainda mais, podendo usar a função mouse junto om os botões, imagina algum sistema ou forma de jogar onde se usa dois mouses ao mesmo tempo.
# 8. <a href="https://www.youtube.com/watch?v=3wZhr6-CNYE&amp;t=586">9:46</a> de fato nenhuma empresa principal (Sony, Microsoft, Steam) do mercado de games fez a função mouse nos controles, POREM a Lenovo fez em seu Legion Go, então não é de fato inovação (como algo criado/inventado pela nintendo, algo que ninguém nunca tinha feito antes), mas é uma função extremamente bem vinda e pode ser que a nintendo inove mostrando uma utilização mais bem desenvolvida ou prática para uso no dia a dia.
# 9. Em <a href="https://www.youtube.com/watch?v=rAPjNqGFgQk&amp;t=339">5:39</a> passou bem rápido, mas vi a imagem de um Joy-con diferente, parece um modelo mais ergonômico,  e tbm sendo usado como mouse.
# 10. já sinto a tendinite só de ver a ergonomia desse &quot;mouse&quot;
#
# 🔹 **Exemplos do Cluster 11:**
# 1. Gente da central amoooo vocês.
# 2. Excelente quinta-feira pra você Edu
# 3. vim mais rápido que piloto de formula 1
# 4. e esses canhões de fumaça ai?
# 5. Acessível e Brasil na mesma frase não existe e nunca existiu.<br>Brasileiro tem mania de normalizar coisas ruins e aceitar tudo como se fosse super normal, sem contar os que bate palma e passa pano pra muitas coisas.<br>Ai as coisas vai piorando cada vez mais, e os banana acha que antes era bom, não era bom, só era menos ruim.<br>Infelizmente ou pagamos o absurdo cobrado ou vai procurar fazer outra coisa.
# 6. Cara, eu acho o Angelo super simpático e tal, mas sou só eu ou ele sempre parece muito mais perdido e por fora das coisas do que o Bruno e o Breno?
# 7. O Monstro está Saindo da Jaula.
# 8. Eu amo  que o oculos  faz o  rosto do  ph distorcer  kkkkkk
# 9. Que venha Massa
# 10. Mais um item na planilha do mês 😏😏😏😏
#
# 🔹 **Exemplos do Cluster 12:**
# 1. Switch 2 será mais fraco do que o steam Deck.
# 2. Pra quem duvidou do Switch 2 LCD 4K, tá aí 4K de reais 😅
# 3. Uma pena ainda não estar em full hd pra gente ver todo o garbo e elegância do Edu, e do Switch 2.
# 4. Eu me surpreenderia se o switch 2 tivesse um navegador. Mas sabemos que isso jamais existiria!
# 5. Switch 2 pode vir quebrado que eu compro do mesmo jeiro
# 6. Não renovei meu switch on-line na esperança que eles façam algo descente no switch 2. Só pagava pq precisava pra rodar alguns jogos que precisavam do passe pra jogar.
# 7. Switch 2 é moderno por fora e antigo por dentro hahaha
# 8. Na minha conta, é 7.2x o switch portátil, e 7.8x o switch no dock.
# 9. O Switch 2 está demais, muito lindo!
# 10. switch online é paia demais.
#
# 🔹 **Exemplos do Cluster 13:**
# 1. <a href="https://www.youtube.com/watch?v=3sazf2jyKZo&amp;t=130">2:10</a> Eu sei que é boa, e quase nem parece 8 bits. XD
# 2. Wow I used an Ai voice translator on this video &amp; omg it worked! Your voice in Eng by the Ai is on point &amp; scary at the same time. There was no errors.
# 3. São os 12 primeiros segundos mais fortes já vistos em um vídeo do PH.<br>E mesmo assim não serão fortes o suficiente para a implacável pergunta:   &quot;Tá, mas qual é a data e preço, PH ?&quot;
# 4. <a href="https://www.youtube.com/watch?v=tt9whasLXIY&amp;t=315">5:15</a> O MK do Swtch parece The Sims
# 5. <a href="https://www.youtube.com/watch?v=YpWQGtUfVOA&amp;t=218">3:38</a> então pra vc maior é melhor 🤭
# 6. <a href="https://www.youtube.com/watch?v=31BvwbyZG-4&amp;t=730">12:10</a><br>Caramba conseguimos Polybius 2 antes de GTA VI 💀
# 7. <a href="https://www.youtube.com/watch?v=lGBSp4CzFS8&amp;t=295">04:55</a><br>&quot;Você consegue sentir quantas bolas tem&quot;😂
# 8. &quot;tô muito feliz, tomamos no cool&quot; o video todo resumido na frase final
# 9. cade o link do video?
# 10. <a href="https://www.youtube.com/watch?v=smy2D9-raQ8&amp;t=135">2:15</a> O Adriano hiperfocado nas fumacinhas kkkk
#
# 🔹 **Exemplos do Cluster 14:**
# 1. Dito isso preço cheio nos jogos sem legenda e dublagem, obrigado por jogar 🥰🥰
# 2. Meu sonho é a interface ser interativa e estilizada igual do 3DS, com menu intuitivo, modelos 3d para o icone dos jogos, com uma e-shop com musiquinha😭😭
# 3. Da pra jogar alguma jogo de pokémon no Oscar 2025😂
# 4. Eu quero é um sistema melhor de metrica de jogos, quanto tempo a gente joga e mais estatísticas, o sistema do 3ds era tão bom
# 5. Quando desbloqueado será que vai roda jogos como Elder ring sem ter que espelhar do pc
# 6. Eu pensei em games educacionais como acontecia nos consoles antigos
# 7. Queria que o HD rumble fosse mais explorado
# 8. pra jogar pokemon, mario e zelda vai dar pra jogar lisinho, então fod*** os jogos multi, quer jogar jogo  multi é ps5 pro e PC
# 9. os novos zeldas e marios estarão ainda mais potentes
# 10. GTA 6 sem chance, o 5 sim é possível.
#
# 🔹 **Exemplos do Cluster 15:**
# 1. Eu chuto 399 dólares lá nos EUA. Os jogos digitais no Brasil vai ficar em 349 reais e os jogos físicos 399 reais.
# 2. O produto: 300 dólares<br>O br:certo entao, 10 mil reais.
# 3. Caixa maior não vai custar mais no transporte? O cartucho é tão pequeno pra que caixa 50x maior?
# 4. O bicho vai ser uns 4k
# 5. Pra mim vai ser 350 dólares, porque por mais de  R$ 3.500 eu não compro haha... E eu espero, afinal &quot;o homem paciente é imbatível&quot;.
# 6. Vai custar no Br cerca de 4500 reais. É daí pra cima, galera.
# 7. Por favor seja barato 😢😢😢😢😢
# 8. 4000 reais só ! Kkkk e os jogos ? Cada um custando 400 reais ! Kkkkk vc n vai comprar um vídeo game desses pra jogar um jogo só, digamos que vc queira 2 jogos novos iai ? 4800,00 reais ! E se quiser comprar mais 2 jogos em um mês ? Mais 800 conto, o dólar tá caro e inflação tá absurdo sim mas o valor que a Nintendo tá pedindo no consoles em dólar tá caro sim ! Tá no msm preço do ps5 praticamente, e o valor que ela cobra nos jogos é algo que nunca vai ter fundamento nem coerência! É bizarro de mais !
# 9. aqui no BR é sempre assim, pega o preço em dólar e multiplica por 10
# 10. só quero ver o precinho que vai vir pra nós rsrsrsrs
#
# 🔹 **Exemplos do Cluster 16:**
# 1. Um Mario 3D Maker? Já imaginaram a possibilidade de montar cenários a nível Super Mario 64 até o Odyssey? Seria épico e com o uso do mouse para montar cada parte do cenário.
# 2. Ideia para jogo!!<br>Boa tarde coelho! Blz? No seu último vídeo, você falou para mandar ideias de jogo para o canal.. tenho uma.<br><br>Resumão: uma coruja rouba o switch de um coelhinho, objetivou, recuperar o switão.<br><br>A coruja tem uma jóia que a transforma e lhe dá poderes e habilidades. <br>O clã dos coelhos também tem. Então o nosso coelhinho pede permissão para pegar essa jóia e ir atrás da coruja, pois não só ele, vários outros coelhos tiveram seus switchs roubados.<br><br>Mas tem um problema, eles são pacíficos, não tem costume de batalhar e por tanto ele não sabe como usar todas as habilidades.<br>Como isso afeta a gameplay?<br>Assim como em jogos de luta você tem que dar vários comandos para usar ataques especiais, o jogador precisa realizar alguns para usar ataques mais poderosos e isso já está liberado desde o início do jogo, afinal o coelhinho já tem a joia com ele. Porém, como ele não sabe usar, isso causa um efeito colateral, terremotos com pedras ou outros matérias E etc..<br><br>Mas conforme ele vai encontrando pergaminhos escondidos nas fases, que ensinam os comandos, ele para de sofrer efeitos colaterais desses golpes que ele aprendeu.<br><br>Fiz até um rascunho que iria passar para o digital, mas vou mandar como está no papel... Gosto de desenhar, então rapidamente pensei num desing...<br><br>Infelizmente não sei programar, mas gostaria de contribuir para a produção do jogo se achar que essa ideia pode ter futuro..<br><br>Mandei no PV só insta, mas vou mandar aqui também.
# 3. Jogo estilo metroidvania
# 4. <a href="https://www.youtube.com/watch?v=31BvwbyZG-4&amp;t=787">13:07</a> Jogo do Coelho tinha que ser um  jogo que você viaja até o Japão e lá você vai conhecendo curiosidades do país de forma que cada fase faça referência a um estilo de jogo com referência a Nintendo, tipo plataforma como mario bros, rpg, pikmin, mario kart, mario party,  donkey kong e etc.. e eh claro que poderia ter animação curtindo as músicas!  No final poderia ser na sede da Nintendo procurando o Switch 2 e quando descobrisse, falaria que a continuação é pro Switch 2!
# 5. <a href="https://www.youtube.com/watch?v=31BvwbyZG-4&amp;t=780">13:00</a> Ideia de jogo do Coelho:<br>A inspiração é algo entre o Bart Simpsons’ Nightmare e Mickey’s Castle of Illusion, onde cada fase mostra um cenário com gameplay e desafio diferente. <br>Mas no caso do Coelho, é ele NO Japão, se hospedando num hotel maluco, onde ele fica preso, e pra sair, vai ter que explorar várias portas desse hotel, em que cada uma tem uma fase com desafios diferentes.
# 6. IDEIA DE JOGO PRO CANAL:<br><br>- PIXEL ARTE 2D LINDA<br>- SE PASSA NO JAPÃO<br>- CADA FASE UM LOCAL DE LA<br>- BEAT N UP (TIPO TARTARUGAS NINJA) ou plataforma<br>- PROTAGONISTA É O COELHO COM SEU BONÉ<br>- O ESPECIAL FAZ ELE VIRAR UM COELHO ou chamar um Coelho companion<br><br>- COLECIONAVEIS DA FASE:: ACHAR O PEDROCA ESCONDIDO NAS FASES JOGANDO GAMES<br><br>- ITENS FINANCEIRO: PACOTES COM A MARCA DO NINTENDO BARATO (mostra que vc economiza)<br><br>- A PONTUAÇÃO DAS FASES SAO medidas igual AS NOTAS DE RANKING DO CANAL<br><br>- Trilha sonora: feita pelo guitarrista de atena ou pela banda que toca nos coelho awards<br><br>OBJETIVO e LORE:: passar por lugares importants da Nintendo no japao ou do proprio Japao, até achar o video game do Coelho que foi roubado por um hater<br><br>DLC: BRASIL
# 7. Esse novo Mário Kart ta com uma carinha que vai ter um modo exclusivo alá Cruis&#39;n USA, só que Cruis&#39;n Mario World, onde as pistas nao tem voltas, são mais longas e vão ligando de uma região à outra. E assim o player vai acompanhando a mudança de ambientação, como vegetação, geografia, clima etc 😮
# 8. <a href="https://www.youtube.com/watch?v=NIlJc_zzUIw&amp;t=380">6:20</a> Ninguém fala, mais o Modelo que mudou muito também foi o do Mario e do Luigi, eles estão com o mesmo estilo do Mario Wonder é só comparar os dois modelos do Mario que a diferença é perceptível.  Sem contar que este modelo de Kart parece um pouco diferente do que estamos abtuados a ver em MK8. Sem contar que no minuto <a href="https://www.youtube.com/watch?v=NIlJc_zzUIw&amp;t=383">6:23</a> o boost no chão esta diferente do MK8 e MK8 DLX.
# 9. Lembor de mario e wario no snes que tinha que usar o mouse, era de puzzle, muito bom o game na pegada de mario vs donkey kong do gba
# 10. 💁🏻‍♂️Espero q lancem um novo Mega Man no estilo do Nintendinho🎮🤩😍😎🍷🗿
#
# 🔹 **Exemplos do Cluster 17:**
# 1. Switch 2, só 6 meses depois, no mínimo, porque early adopter só se ferra. E sim, tem que sair por volta de 3000. E os games tem que custar no máximo os 300 reais que custam agora os do Switch original (e esses tem que ter uma boa queda de preço).
# 2. Legal que vai lançar o switch 2. Dito isso, vou comprar o switch lite. Preço de lançamento não dá não, e ainda tem chances de vir com algum problema de primeira leva de console, coisa que quase sempre tem.
# 3. Será que a Nintendo vai abaixar o preço do OLED pra 299 e tirar o V2 de linha?
# 4. Se a Nintendo demorar mais uns 15 dias pra anunciar esse negócio, vão tar vendendo uma versão &quot;original&quot; dele na 25 de março 😂
# 5. A resposta é óbvia: como o Switch 2 vai rodar praticamente tudo do 1, o negócio é esperar uns 2 anos para ver se o Switch 2 não vem com defeito de fabricação nos joy-con ou em outra parte, daí compra.
# 6. Switch 2 &quot;POSSIVELMENTE&quot; estará na média dos 4k...<br><br>Switch 1 FAZ TODO SENTIDO NÃO CAIR DE PREÇO... pois, só pelo simples fato de o Switch 2 ser retrocompatível, o Switch 1 ainda vai bombar de vendas.
# 7. Um dos comentaristas da Bloomberg afirmou que : se o preço do Nintendo switch 2 for 400 ou menos eles irão anunciar em abril se for mais do que 400 não anunciarão! Na época o preço do 3ds não caiu 100 doletas mas 80!
# 8. tenho meu questionario rapido:<br><br>1- vc tem um switch? <br>2- vc tem os possíveis R$3,500+ que isso vai chegar aqui pra pegar o switch 2?<br>3- vc vai  pagar os 450/400 reais que os jogos de switch 2 vao custar ou vai chorar igual vc ja chora pra pagar 250+ no switch atual? ($70)<br><br>se respondeu não pra pelo menos 2 dessas, pega o switch cara, 1800 novo, pra vc que n quer gastar, pode meter o chip (que nao vai ter no 2, entao se vc chora em pagar 250+ reais em jogo de switch, imagina os 400 do switch 2)  fora que vai ter quer esperar 1 ano de switch 2 pra começarem as promoçoes relevantes de preço do switch 2 e finalmente matar a vontade de jogar switch 1 e 2 com a retrocompatibilidade
# 9. Acredito que muita gente vai comprar o SWITCH 2 no lançamento, o problema é que os lojista é zóio grande e vai aumentar o preço absurdo e vai culpa a alta do dólar. 😂
# 10. O preço acima do PS5 não vai ser, provavelmente. Estou ancioso para ver a caixa do meu aqui na prateleira, se vier com imagem inferior ao Oled em qualidade talvez resista e espere o Nintendo Switch 2 Oled mais na frente, irei aguardar as análises posteriores para tomar a decisão da compra.
#
# 🔹 **Exemplos do Cluster 18:**
# 1. Quando foi filmado? Porque a Nintendo já confirmou que o próximo console terá retrocompatibilidade com os jogos do Switch.
# 2. Retrocompatibilidade 🙏🏻🙏🏻🙏🏻
# 3. A retrocompatibilidade vai ajudar a alvancar as vendas no começo
# 4. A retrocompatibilidade foi confirmada anteriormente pela Nintendo.
# 5. Tem uma mensagem no X da Nintendo Japão em novembro/2024 do Furukawa dizendo que terá a retrocompatibilidade. E online funcionará igual. E que os cartuchos antigos também vão funcionar
# 6. Vim trazer a informação que o próprio presidente da Nintendo anunciou que o Switch 2 vai ser retro compatível com o Switch 1.
# 7. Essa retrocompatibilidade me faz cogitar comprar games que eu passava longe por causa do desempenho....agora real faz sentido ter games como Hogwarts Legacy e outros ports impossíveis, ja pensando no melhor desempenho do switch 2.
# 8. Se tiver retrocompatibilidade, vou seguir de MIG Switch até o dia que tiver jogo online que presta!
# 9. <a href="https://www.youtube.com/watch?v=YpWQGtUfVOA&amp;t=193">3:13</a> Nintendo confirmou que vai ser retrocompativel!
# 10. O ds e o 3ds também já vinham com retrocompatibilidade nativa via hardware
#
# 🔹 **Exemplos do Cluster 19:**
# 1. Isso que o PH falou já me anima bastante. <br><br>E fico mais feliz com os jogos da Nintendo que são mega otimizados. Dá pra fazer uns jogos belíssimos com o poder do Switch 2
# 2. Eu, como não tive o Switch e fiquei sem jogar os jogos da Nintendo essa geração toda que durou muito tempo fico feliz que o novo vai ser compatível com tudo e estou ansioso para poder jogar nele.
# 3. Tenho o Series S mas estou muito empolgado pelo Switch 2, principalmente pelo apoio da Microsoft a ele.
# 4. Estou torcendo muito que os jogos do Switch 1 tenham algum tipo de melhorias quando coloca no Switch 2.
# 5. Acho que valia a pena fazer uma análise às retro consolas multi-jogos do Alix que estão tão na moda e me parecem uma boa compra nos dias que correm
# 6. Leva mal não,eu amo meu Nintendo Switch. Más Nintendo Switch online é um lixo! Não tem sequer Super Bomberman. Assino só porque jogo online. Mil vezes mais emular um jogo de um game portátil simples.
# 7. to interessado em pegar o switch 2 quando lançar (a depender do preço tbm né kk), vai sair com retro compatibilidade total com o switch 1, que tem uma biblioteca de jogos imensa, e acho que vai ter uma avalanche de jogos nele, ja até imagino que empresas como ubisoft, ea, activision, etc devem ta babando na oportunidade de lançar vários jogos da ultima década no switch 2 que não rodavam no switch 1 (como assassin&#39;s creed, farcry, cod, etc)
# 8. Por mais que tenham muitos jogos incríveis third party que vão chegar pro Switch, eu mal posso esperar pelos jogos first party, Super Mario Odyssey, os Zeldas, Kirby, Luigi&#39;s Mansion 3... Todos jogos LINDOS que eles conseguiram fazer mesmo com as limitações do Switch, pro Switch 2 eu imagino que a Nintendo vai chutar o balde e trazer umas obras primas.
# 9. Eu fico contente de imaginar que possivelmente o Switch 2 rodará de maneira bem satisfatória jogos AAA, isso significa que o apoio vai ser ainda maior dado que o trabalho de port vai ser bem menor. <br><br>Curioso mesmo eu estou com a retrocompatibilidade, se eles pretendem de alguma forma otimizar loadings ou estabilizar FPS nos exclusivos que tiveram gargalos com isso no hardware do Switch 1<br><br>Unica tela de loading que eu gosto e apoio que demore é a Samus no elevador em Metroid Dread kkkkkk
# 10. Eu to animado pra poder melhorar os gráficos do meu Dead By Daylight, acostumei no PS5 agora não consigo mais jogar no Switch :(

# %%
from sklearn.manifold import TSNE
import seaborn as sns

tsne = TSNE(n_components=2, random_state=42)
embeddings_2d = tsne.fit_transform(embeddings)

df_viz = pd.DataFrame({"x": embeddings_2d[:, 0], "y": embeddings_2d[:, 1], "cluster": labels})
plt.figure(figsize=(8, 6))
sns.scatterplot(x="x", y="y", hue="cluster", data=df_viz, palette="tab10")
plt.title("Visualização dos Clusters com t-SNE")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# Ajustar PCA nos embeddings
pca = PCA()
pca.fit(embeddings)

# Variância explicada acumulada
explained_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# Plotar o gráfico da variância explicada
plt.figure(figsize=(6,4))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='--')
plt.xlabel("Número de Componentes Principais")
plt.ylabel("Variância Explicada Acumulada")
plt.title("Escolha do Número de Componentes no PCA")
plt.axhline(y=0.95, color='r', linestyle='--', label='95% de variância explicada')
plt.legend()
plt.show()

# %%
num_components = 350  # Escolha com base no gráfico

pca = PCA(n_components=num_components)
embeddings_pca = pca.fit_transform(embeddings)

# %%
ks = range(1, 15)
inertias = []

for k in ks:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(embeddings_pca)
    inertias.append(kmeans.inertia_)

# Plotar o método do cotovelo
plt.figure(figsize=(6,4))
plt.plot(ks, inertias, marker='o', linestyle='--')
plt.xlabel("Número de Clusters (K)")
plt.ylabel("Inércia (Soma das Distâncias)")
plt.title("Método do Cotovelo para Escolha do K")
plt.show()

# %%
import faiss
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# 🔹 Reduzir a dimensionalidade com PCA para analisar o número ideal de clusters
def calcular_k_pca(embeddings, variancia_min=0.95):
    pca = PCA().fit(embeddings)
    variancia_acumulada = np.cumsum(pca.explained_variance_ratio_)

    # Encontrar o número mínimo de componentes que explicam pelo menos 95% da variância
    k_pca = np.argmax(variancia_acumulada >= variancia_min) + 1

    # Aplicar a transformação PCA para reduzir dimensionalidade
    pca_embeddings = PCA(n_components=k_pca).fit_transform(embeddings)

    # Plotando a variância explicada
    plt.figure(figsize=(8,5))
    plt.plot(variancia_acumulada, marker="o")
    plt.axhline(y=variancia_min, color='r', linestyle="--", label=f"{variancia_min*100:.0f}% de variância explicada")
    plt.xlabel("Número de Componentes Principais")
    plt.ylabel("Variância Explicada Acumulada")
    plt.title("Escolha do Número de Componentes no PCA")
    plt.legend()
    plt.show()

    print(f"🔹 Número de componentes sugerido pelo PCA: {k_pca}")
    return k_pca, pca_embeddings  # Retorna também os embeddings reduzidos

# 🔹 Método do cotovelo para escolha numérica do K
def encontrar_melhor_k(embeddings, k_min=2, k_max=15):
    inercia = []
    ks = list(range(k_min, k_max + 1))

    for k in ks:
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        kmeans.fit(embeddings)
        inercia.append(kmeans.inertia_)

    # Diferença de inclinação entre pontos consecutivos
    variacoes = np.diff(inercia)

    # Definição do ponto do "cotovelo"
    melhor_k = ks[np.argmin(variacoes[:k_max-2]) + 1]

    # Plotar a curva de inércia
    plt.figure(figsize=(8,5))
    plt.plot(ks, inercia, marker="o", linestyle="--")
    plt.axvline(melhor_k, color="r", linestyle="--", label=f"K escolhido = {melhor_k}")
    plt.xlabel("Número de Clusters (K)")
    plt.ylabel("Inércia (Soma das Distâncias)")
    plt.title("Método do Cotovelo para Escolha do K")
    plt.legend()
    plt.show()

    print(f"🔹 Melhor número de clusters encontrado: {melhor_k}")
    return melhor_k

# 🔹 Função para rodar FAISS com o K-Means
def rodar_kmeans_faiss(embeddings, k):
    print(f"\n🚀 Rodando K-Means com FAISS para K = {k}")
    
    # Definir FAISS KMeans
    kmeans = faiss.Kmeans(d=embeddings.shape[1], k=k, niter=300, nredo=10, spherical=True)
    kmeans.train(embeddings)

    # Atribuir clusters
    _, labels = kmeans.index.search(embeddings, 1)
    labels = labels.flatten()

    return labels

# 🔹 Função para exibir exemplos de cada cluster
def mostrar_exemplos_clusters(textos_originais, labels):
    df = pd.DataFrame({"text": textos_originais, "cluster": labels})

    for cluster_id in sorted(df["cluster"].unique()):
        print(f"\n🔹 **Exemplos do Cluster {cluster_id}:**")
        exemplos = df[df["cluster"] == cluster_id]["text"]
        if exemplos.shape[0] < 10:
            exemplos = exemplos.sample(exemplos.shape[0], random_state=42)  # Evita erro se houver poucos exemplos
        else:
            exemplos = exemplos.sample(10, random_state=42)  # Pegando 10 exemplos
        
        for idx, texto in enumerate(exemplos, start=1):
            print(f"{idx}. {texto}")

# 🔹 Pipeline de Clustering
def pipeline_clustering(embeddings, textos_originais):
    # Passo 1: Determinar K pelo PCA e reduzir dimensionalidade
    k_pca, pca_embeddings = calcular_k_pca(embeddings)

    # Passo 2: Determinar K pelo cotovelo usando os embeddings reduzidos
    k_elbow = encontrar_melhor_k(pca_embeddings)  # Usando pca_embeddings aqui

    k_final = k_elbow 

    print(f"\n🔹 Testando FAISS K-Means com K = {k_final}")

    # Rodar K-Means com FAISS nos embeddings reduzidos
    labels = rodar_kmeans_faiss(pca_embeddings, k_final)

    # Mostrar exemplos dos clusters
    mostrar_exemplos_clusters(textos_originais, labels)

# 🔹 Verifica se os embeddings estão disponíveis
if 'embeddings' not in locals():
    raise ValueError("❌ ERRO: A variável `embeddings` não foi definida. Carregue os embeddings antes de rodar.")

if 'textos_originais' not in locals():
    raise ValueError("❌ ERRO: A variável `textos_originais` não foi definida.")

# 🚀 Rodar o pipeline de clustering
pipeline_clustering(embeddings, textos_originais)
# Out:
# 🔹 Número de componentes sugerido pelo PCA: 543
# 🔹 Melhor número de clusters encontrado: 3
#
# 🔹 Testando FAISS K-Means com K = 3
#
# 🚀 Rodando K-Means com FAISS para K = 3
#
# 🔹 **Exemplos do Cluster 0:**
# 1. Boa tarde, eu tenho uma duvida que não tem nada a ver com a publicação, se poderem me responder eu vou ficar agradecida. Porque quando fala o nome do Xenoblade eles leem com &quot;Z&quot; em vez de &quot;X&quot;? Muito obrigada a todos!!!
# 2. Eles sabem o q eles estão fazendo quando fazem uma Gardevoir. Eles quem financiam essa doença hahaha
# 3. Eu te amo, PH, eu te amo
# 4. Não sei se entendi a lógica sobre o período agosto-outubro. Qual a diferença entre o Lite e o OLED que lançaram em setembro e outubro? Um período também que costumam lançar edições especiais.<br><br>Enfim, de qualquer forma também concordo que de Julho não passa. Bem provável ser Junho
# 5. caralho que saudades que tava de ver os videos do damiani
# 6. ELA TA CERTA kkkk
# 7. Para mim só troco meu oled si tiver sistema de conquista troféu
# 8. Damiani a saudade que eu estava dos seus videos não tá escrito rapaz! bem vindo de volta!!
# 9. PH from Brazil
# 10. O vazamento ta errado quanto a tecnolgia da gpu, é da série 30, nao da 20.
#
# 🔹 **Exemplos do Cluster 1:**
# 1. pra jogar pokemon, mario e zelda vai dar pra jogar lisinho, então fod*** os jogos multi, quer jogar jogo  multi é ps5 pro e PC
# 2. Será que vai ter sistemas de trofeus igual a steam e ps4 e xbox
# 3. tudo que eu quero é que ele seja forte o suficiente pra tirar a Sony do pedestal, Playstation mais do que nunca precisa de um rival, de uma concorrência que faça eles voltarem aos eixos e quem sabe arriscar em jogos mais criativos e não apenas em seguir a tendências
# 4. E não esqueça que não é só um mouse, os dois controles podem ser usados com função de mouse ao mesmo tempo, imagina algum sistema trabalhando com dois mouses, ou algum estilo de jogo novo que use isso, maluco né?
# 5. Se tiver retrocompatibilidade, vou seguir de MIG Switch até o dia que tiver jogo online que presta!
# 6. Kogu tá ansioso pro novo Zelda ?
# 7. Se tiver ecrã maior, pouco mais de bateria e mais potência para receber pelo menos jogos da geração passada será um sucesso gigante
# 8. Para quem só acredita vendo, tá aí é mouse mesmo! As aplicações disso vão ser bem interessantes! Já pensou se a Nintendo tiver feito todo um sistema operacional que usando o mouse lembre um PC, com suporte a vários aplicativos e etc.
# 9. Como assim ninguém fala que Donkey Kong é obra prima? Tanto o Returns quanto o Tropical Freeze são considerados obras primas, eu entendo nao ser fã de Nintendo mas falar que é so mario e zelda é o mesmo que eu vir aqui falar que PlayStation é so daleste e gta
# 10. PLS! Take my money, Nintendo. 😂
#
# 🔹 **Exemplos do Cluster 2:**
# 1. resumindo, vai ser possível qualquer porte para o nintendo switch, isso inclui até gta 6  poderá ser possível. Resta esperar saber se as desenvolvedoras vão conseguir usar essa tecnolgia na prática.
# 2. xbox sx e ps5 estão na reta final da geração, a nintendo tem que jogar uma parada potente, o switão na verdade é muito ruim perto da geração passada, se não lançar logo um game potente antes do anuncio do  proximo xbox e PS vai se ferrar muito, acho que as proximas gerações serao de portateis hibridos.
# 3. A Nintendo já confirmou a retrocompatibilidade do próximo console com o Switch pelo menos.
# 4. CARA TEM QUE TER PHASMOPHOBIA PARA O NINTENDO SWITCH 2
# 5. É muito acessível no Japão. Há lojas de usados que compram seu console e você sai de lá com um novo. Assim que fiz para ter o Switch Oled. Se os preços forem esses mesmos, o Switch 2 custará um pouco mais que o atual Switch Oled.
# 6. Não duvido que venha por 400 usd e por volta de 3500 reais, mas o problema pra mim são os jogos, tivemos recentemente os jogos vindo com aumento mais uma vez, mídia física 350 reais, localização de preço não é conversão, isso é fora da realidade do Brasil, eu já perdi o hype de pegar o Switch 2 no lançamento por conta disso, essa politica de preço dos jogos por aqui me trás uma perspectiva muito ruim.
# 7. Sobre a deal4b, ja troquei joycon com eles 2 vezes, a primeira foi extremamente veloz, cerca de 2 dias em 2021. Fiz o processo recentemente também por conta de drift dnv, já estão me enviando joy cons novos
# 8. Melhor se n fosse serviço e sim comprado msm , inclusive em midia fisica .switch online n presta, desisti e desbloqueei o meu , inclusive indico. Se tivesse mídia física dos jogos retro seria mais interessante q esses serviço online da nintendo. Quem sabe com o switch 2 seja melhor
# 9. quero saber e do design n quero saber e da potencia do switch 2
# 10. A nintendo só precisa fazer o switch mais potente e lançar jogo novo pro switch 2 kkkk e vai vender muito

# %%
from sklearn.mixture import GaussianMixture
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE

# Encontrar o número ideal de clusters usando BIC
bic_scores = []
k_values = range(2, 11)  # Testamos de 2 a 10 clusters

for k in k_values:
    gmm = GaussianMixture(n_components=k, covariance_type='full', random_state=42)
    gmm.fit(embeddings)
    bic_scores.append(gmm.bic(embeddings))  # Salvar o BIC

# Definir o melhor número de clusters (menor BIC)
best_k = k_values[np.argmin(bic_scores)]
print(f"Número ideal de clusters: {best_k}")

# Treinar o modelo GMM com o melhor k
gmm = GaussianMixture(n_components=best_k, covariance_type='full', random_state=42)
clusters = gmm.fit_predict(embeddings)

# Reduzir dimensionalidade para 2D com t-SNE para visualização
tsne = TSNE(n_components=2, random_state=42)
embeddings_2d = tsne.fit_transform(embeddings)

# Criar DataFrame para visualização
import pandas as pd
df_viz = pd.DataFrame({
    "x": embeddings_2d[:, 0],
    "y": embeddings_2d[:, 1],
    "cluster": clusters
})

# Plot dos clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(x="x", y="y", hue="cluster", data=df_viz, palette="tab10")
plt.title("Clusters identificados com GMM")
plt.show()
# Out:
# Número ideal de clusters: 2

# %%
import umap
import hdbscan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Reduzir dimensionalidade com UMAP (de embeddings originais para 2D)
umap_reducer = umap.UMAP(n_components=500, random_state=42)
embeddings_2d = umap_reducer.fit_transform(embeddings)

# Rodar HDBSCAN para encontrar clusters automaticamente
hdbscan_cluster = hdbscan.HDBSCAN(min_cluster_size=25, min_samples=3, cluster_selection_method='eom')
clusters = hdbscan_cluster.fit_predict(embeddings)

# Criar DataFrame para visualização
df_viz = pd.DataFrame({
    "x": embeddings_2d[:, 0],
    "y": embeddings_2d[:, 1],
    "cluster": clusters
})

# Plot dos clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(x="x", y="y", hue="cluster", data=df_viz, palette="tab10")
plt.title("Clusters identificados com UMAP + HDBSCAN")
plt.show()

# Mostrar quantos clusters foram detectados
num_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)  # "-1" são pontos considerados ruído
print(f"Número de clusters detectados: {num_clusters}")
# Out:
# C:\Users\Victor\.conda\envs\fiap_tech2\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Victor\.conda\envs\fiap_tech2\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\Victor\.conda\envs\fiap_tech2\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Victor\.conda\envs\fiap_tech2\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Número de clusters detectados: 0
