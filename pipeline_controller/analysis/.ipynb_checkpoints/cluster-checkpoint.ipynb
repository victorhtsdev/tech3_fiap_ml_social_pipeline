# %%
import psycopg2
import pandas as pd
import numpy as np

# %%
# Definir a URL do banco de dados
DATABASE_URL = "postgresql://postgres:super#@localhost:5432/ml_social_db"

# Conectar ao banco de dados
conn = psycopg2.connect(DATABASE_URL)
cursor = conn.cursor()

# %%
# Definir o ID para filtragem (hardcoded)
id_filtrado = 'f7ccff53-7699-4add-bc0c-fc97176585a7' 

# Buscar embeddings e textos da tabela
cursor.execute("""
    SELECT embeddings, content FROM content 
    WHERE id = %s;
""", (id_filtrado,))
data = cursor.fetchall()

# Fechar conexão com o banco
cursor.close()
conn.close()

# %%
# Converter os embeddings (BYTEA para array NumPy)
embeddings = np.array([np.frombuffer(row[0], dtype=np.float32) for row in data])
textos_originais = [row[1] for row in data]

# Verificar a dimensão dos embeddings
print(f"Shape dos embeddings: {embeddings.shape}")  # Deve ser (n_samples, n_features)
# Out:
# Shape dos embeddings: (1401, 1536)

# %%
import faiss
k = 15 # Definir número de clusters
kmeans = faiss.Kmeans(d=embeddings.shape[1], k=k, niter=500, nredo=50, spherical=True)

# Treinar modelo
kmeans.train(embeddings)

# Atribuir clusters
_, labels = kmeans.index.search(embeddings, 1)
labels = labels.flatten()

# Criar DataFrame para analisar os clusters
df = pd.DataFrame({"text": textos_originais, "cluster": labels})

# Exibir exemplos de cada cluster
for cluster_id in sorted(df["cluster"].unique()):
    print(f"\n🔹 **Exemplos do Cluster {cluster_id}:**")
    exemplos = df[df["cluster"] == cluster_id]["text"].sample(10, random_state=42)  # Pegando 5 exemplos
    for idx, texto in enumerate(exemplos, start=1):
        print(f"{idx}. {texto}")
# Out:
# 🔹 **Exemplos do Cluster 0:**
# 1. Esperava uma placa de lá de 2022... Mas paciência. Vai vir meio defasado, mas pode ser por causa de custo.
# 2. Esperando o desbloqueio. 😂
# 3. Quando tiver o desbloqueio dele, vai ser uma delicinha
# 4. Microsoft gastou uma grana comprando estúdios agora o investimento tem que se pagar o mais rápido possível. Investidor de área cultural não gosta de esperar
# 5. <a href="https://www.youtube.com/watch?v=AEvCxY_7mFk&amp;t=198">3:18</a> Como que vai quebrar o conectar se ele fica escondido no recuo… não fica exposto.
# 6. Seu eu não quiser blusa os controles eu vou conseguir usa o touch ,.?
# 7. Essa língua pra receber o joy con parece ser uma placa ME QUEBRA
# 8. Amigo, tenho vontade de comer o meu primeiro e gostaria de saber a sua opinião sobre eu comprar este que está no mercado ou aguardar e comprar este novo? Obrigado
# 9. Retrocompatibilidade é muito bommmmm
# 10. gostaria de fazer uma pergunta ao pessoal do canaltech. Comprei um celular na loja lacrado, mas quando fui nos arquivos do celular tinha audios de whatsapp e fotos de pessoas que não eram minhas e nem de pessoas conhecidas, e não foi o primerio celular que aconteceu isso. o que esta acontecendo ?
#
# 🔹 **Exemplos do Cluster 1:**
# 1. Excelente vídeo. Só uma correção: Nintendinho só tem botões A e B. Foi o Super Nintendo que trouxe o X e Y (além do R e L).
# 2. Por favor que seja nomeado como &quot;Super Nintendo Switch&quot;
# 3. Simplesmente vamos comprar ne! Sucesso Nintendo!
# 4. O PH diz que não é nintendista, mas tem o melhor canal sobre Nintendo. O melhor!!!
# 5. Se tudo que tá vazando for verdade a Nintendo no dia da apresentação só precisa dizer “já tá tudo na internet, tchau” 😂😂😂😂
# 6. Eu acho que a nintendo acertou demais e era isso mesmo que a gente queria um nintendo switch melhorado com mais potência e um design bem pensado adorei já quero o meu<a href="UCWKtHaeXVzUscYGcm0hEunw/CIvP_pCO-dsCFQsCZAod-zIGvQ"></a><a href="UCWKtHaeXVzUscYGcm0hEunw/1O_-XPCtFOXW8wTiprfgCg"></a>
# 7. Lembrando que não é o valor oficial. A Nintendo não divulgou os valores. É rumor.
# 8. O que eu quero mesmo é sistema de trofeús/conquistas. Esse é o maior sonho de milhões de Nintendistas.
# 9. Sucesso,  já tava ba hora de um novo Nintendo
# 10. Vixi agora e bagunça mesmo torando  nossa amada Nintendo 😲😲😲
#
# 🔹 **Exemplos do Cluster 2:**
# 1. 🤩✌️
# 2. Feliz ano novo Dig 🙏
# 3. É sobre isso galeris
# 4. O que você vai fazer com a Gardevoir?🤨
# 5. O dami ta calvo ó
# 6. to hypado
# 7. E esse final 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣
# 8. <a href="https://www.youtube.com/watch?v=oWCscYgvdMo&amp;t=378">6:18</a> omg, A render of blue yoshi with hair i made on deviantart finally made its way into this video lol
# 9. 👍👍👍
# 10. You posted it? I came!
#
# 🔹 **Exemplos do Cluster 3:**
# 1. eu literalmente fiquei doida por um switch pq eu quero jogar zelda echoes of wisdom kkkkkkk esperando o 2 lançar pra saber se vai valer a pena
# 2. <a href="https://www.youtube.com/watch?v=oWCscYgvdMo&amp;t=432">7:12</a> esse donkey kong parece  que viu coisas kkk
# 3. <a href="https://www.youtube.com/watch?v=31BvwbyZG-4&amp;t=780">13:00</a> Ideia de jogo do Coelho:<br>A inspiração é algo entre o Bart Simpsons’ Nightmare e Mickey’s Castle of Illusion, onde cada fase mostra um cenário com gameplay e desafio diferente. <br>Mas no caso do Coelho, é ele NO Japão, se hospedando num hotel maluco, onde ele fica preso, e pra sair, vai ter que explorar várias portas desse hotel, em que cada uma tem uma fase com desafios diferentes.
# 4. Pelo jeito, crossgen só serão jogos bobinhos e portáveis para o switch. Tipo um jogo da peach ou algum zelda no estilo artístico requentado de links awakening.
# 5. Caraca, vc me ajudou a zerar Zelda BotW no lancamento. Tmj man.
# 6. Uma sugestão de vídeos de especulações são os jogos anunciados day 1.<br>Pokemon, Metroid e mario kart 9 são quase garantidos. Não duvido que anunciem junto um novo Zelda e Mario 3d pros próximos anos. Zelda TOTK não ter dlc é um indicio que tão trabalhando a 100% num Zelda novo pro switch 2 talvez há mais de 1 ano
# 7. IDEIA DE JOGO PRO CANAL:<br><br>- PIXEL ARTE 2D LINDA<br>- SE PASSA NO JAPÃO<br>- CADA FASE UM LOCAL DE LA<br>- BEAT N UP (TIPO TARTARUGAS NINJA) ou plataforma<br>- PROTAGONISTA É O COELHO COM SEU BONÉ<br>- O ESPECIAL FAZ ELE VIRAR UM COELHO ou chamar um Coelho companion<br><br>- COLECIONAVEIS DA FASE:: ACHAR O PEDROCA ESCONDIDO NAS FASES JOGANDO GAMES<br><br>- ITENS FINANCEIRO: PACOTES COM A MARCA DO NINTENDO BARATO (mostra que vc economiza)<br><br>- A PONTUAÇÃO DAS FASES SAO medidas igual AS NOTAS DE RANKING DO CANAL<br><br>- Trilha sonora: feita pelo guitarrista de atena ou pela banda que toca nos coelho awards<br><br>OBJETIVO e LORE:: passar por lugares importants da Nintendo no japao ou do proprio Japao, até achar o video game do Coelho que foi roubado por um hater<br><br>DLC: BRASIL
# 8. O asfalto desse Mario kart tá insano. Se prestar atenção tá bem realista msm.
# 9. Deveria sair Rare Replay,Killer Instinct Definitive Edition,<br>Sabrewulf de GBA,Banjo Pilot,<br>Grunty&#39;s Revenge e outros
# 10. Eu lembro do mouse no super Nintendo. Joguei Mario Paint com ele. Muito legal
#
# 🔹 **Exemplos do Cluster 4:**
# 1. vou  comprar  o switch 1 agora
# 2. Essa geração começará de fato com o Switch 2
# 3. Oque eu queria saber é sobre a bateria 🤔 com certeza sera o diferencial entre o switch 2 e a concorrência.
# 4. Moco... mais de 10  anos de switch... eu tinha 11 anos quando vi o video do odiador do switch... e a frequencia do canal só diminuiu kkkk
# 5. Exatamente o meu caso. Comprei o switch OLED no final do ano passado. A intenção é ficar com ele uns 2 anos aproveitando e depois passar pro 2
# 6. Quando o switch 2 vier ao mundo, eu vou morar nesse canal
# 7. Tenho o Series S mas estou muito empolgado pelo Switch 2, principalmente pelo apoio da Microsoft a ele.
# 8. Uma pena ainda não estar em full hd pra gente ver todo o garbo e elegância do Edu, e do Switch 2.
# 9. Phoenix fica gostoso demais quando fala do switch
# 10. O hardware deve ser obviamente mais potente mas a sensação é que estamos vendo um switch XL.
#
# 🔹 **Exemplos do Cluster 5:**
# 1. VOU PODER VER TANTO VÍDEO NOVO AQUI MANO
# 2. <a href="https://www.youtube.com/watch?v=smy2D9-raQ8&amp;t=739">12:19</a> não esperava ver o grito do core aqui kkkkkkk mas de resto um ótimo vídeo com ótimos apresentadores:)
# 3. eu gosto da interface do Spotify, e oq eu mais uso é a playlist de músicas curtidas, faço q nem vc falou, uso como uma rádio q só toca músicas q eu gosto, tenho quase 1000 músicas curtidas, que escuto no aleatório
# 4. caralho, Damiani ta vivo ainda, fazia tempo que nao via nada teu, o YouTube nao me enviava mais notificação
# 5. Diego essa câmera não tá boa! Acho que precisa só configurar melhor! Abraços
# 6. Eu como jovem senhor, me fez lembrar que antigamente digitava um texto na maquina de escrever, para carta ou memo e sempre pedíamos para alguém ler novamente ou em voz alta para vc ouvir ou só corrigir erros ortográficos.<br>Mas esse vídeo ficou bem explicado sobre o assunto!<br>Obgd
# 7. Adoro esses videos de noticias mano! Top demais
# 8. Qualidade dos vídeo ta absurda mica, parabéns.Só na introdução da p ver a qualidade do vídeo, obg por trazer essa qualidade p gente!
# 9. Continue com seu ótimo trabalho, sempre nos informando de forma clara e objetiva
# 10. Parabéns pelos 2 milhões de inscritos
#
# 🔹 **Exemplos do Cluster 6:**
# 1. Nintendo ta tão superior a sony e Microsoft que o seitch 2 é mas divulgado do que o ps5 e os xbox
# 2. O nintendo Wii tinha Netflix. Porem depois de uns 10 anos do lançamento, desativaram. A qualidade nao era boa, demorava bastante. E esse mesmo problema de lentidão está na loja atual do switch, coisa que as outras plataformas nao tem. O foco deles sempre foi o jogo, e o sistema operacional ficou meio de lado. Ainda tenho esperança que estas coisas vão mudar no switch 2, e quem sabe lancem um sistema de conquistas. Agora, se adaptarem o cartucho pra outro tamanho, aí é sacanagem. A nao ser que os cartuchos da geração antiga funcionem também.
# 3. Pô será que a Nintendo vai salvar os consoles de novo, porque se hoje é comum a galera ter um console em casa muito se deve a ela que ganhou a disputa contra os Pc na década de 80
# 4. Nessa parte a Sony peca muito, todo mundo esperando um portátil mandaram a porcaria do PS PORTAL, quem sabe agora ou nunca mais eles acordam pra fazer um Vita 2
# 5. Em 2017, uma galera considerável já reclamava do hardware do Switch.<br>Na época já era um hardware muito defasado.<br>Ótimo que o console deu certo e agradou os fans, mas... Tomara que o próximo faça o mesmo sucesso.
# 6. A unica coisa que queria no novo console era rodar em duas telas como o wii u meu console favorito me fez apaixonar por jogos muito ruim em outros consoles
# 7. A única empresa que mantem sua raiz valoriza seu console é seus exclusivos
# 8. <a href="https://www.youtube.com/watch?v=AEvCxY_7mFk&amp;t=395">6:35</a> ouvi dizer que esses jogos não suportados seriam aqueles que usam acessórios pra funcionar. Por exemplo, ring fit que é parcialmente compatível pois é possível parear os controles antigos no console novo. Porem jogos que usam acessórios que se encaixam na tela não são compatíveis pelo tamanho maior dela
# 9. se lançar gta para o sw2 esquece acaba a geração, a nintendo domina sem apoio ,imagina  com apoio esquece !!
# 10. Switch tem sido o melhor console que eu já tive, tanto que já estou no terceiro kkkkk (peguei o v2, dei de presente pra minhas irmãs e comprei o OLED, e recentemente peguei o Lite de Zelda).
#
# 🔹 **Exemplos do Cluster 7:**
# 1. Geralmente eu sempre espero lançar a segunda ou terceira versão do vídeo game e ainda espero está versão baratear, é tipo o ps5, esperei tanto que consegui perceber que não vale a pena para a minha pessoa ter, já o switch oled me agrada bastante, tive está percepção pq esperei bastante e analisei bastante os dois (meu gosto, nem aí se para alguém o ps5 é melhor, a conversa não é esta)
# 2. <a href="https://www.youtube.com/watch?v=yvgy3fDDmmY&amp;t=797">13:17</a> Mas pelo menos FiFA/FC tem sido lançados novas versões desde de 2018 pro Switch.
# 3. Joycon de Switch continua dando drift mesmo nos modelos mais novos. Mesmo no Oled ou no Lite. A Nintendo passou a geração inteira enrolando pra arrumar esse defeito. Não adianta muita coisa eles trocarem gratuitamente um joycon com drift por outro novo que vai dar drift alguns meses depois....
# 4. Eu acho que uma coisa que a Nintendo poderia implementar um modo “Wii U” , creio que o switch 2 conseguiria fazer streaming pra tv e o switch viraria uma segunda tela
# 5. Lembra em 2020 sobre o papo do Switch PRO não ia acontecer e que provavelmente iria lançar em 2024/2025 e, possivelmente 2026, iria lançar o sucessor e também que o Switch no fim do ano fiscal de 2025 chegaria aos 153-154 mi em vendas.<br><br>Todos riam de mim. Agora acredito que o Nintendo Switch nesse ano fiscal terminará com 152 mi.
# 6. Eu acho  vale a pena. esses 11 Motivos:<br>1. Pra quem nunca teve um switch a biblioteca é imensa,<br>2. A Nintendo ainda vai lançar jogo, <br>3. Provavelmente ele vai ter mais do que retro compatibilidade com o 2 (tipo Remote Play)<br>4. É o console mais barato do mercado atualmente,<br>5. O melhor console para se ter como secundário. <br>6. Pode reclamar o que for da Nintendo, mas os jogos dela não tem comparação, são todos bem feitos e em geral dinheiro bem gasto (tirando pokémon scarlet/violet).<br>7. Os consoles/pc portátil do mercado são absurdamente caro, sem autonomia de bateria (por serem acima de tudo um PC).<br>8. Caso não queira pagar pelo jogos, tem esqueminha...<br>9. Todo gasto em jogos nele pode não vai ser jogado fora, pois vc pode comprar o switch 2 no futuro e os jogos acompanham.<br>10. Futuramente não vai virar um peso de papel, ate pq alguém ainda vai criar um sistema pra ele virar um console pra emular outros... tipo o psp, ai a gente vai pode joga até ps2 nele... vai ser uma delicia...<br>11. Já tive 2 switch e 1 lite, e 0 problemas... não gastei com manutenção... quase 0 problemas que façam você ter que mandar concertar ...
# 7. Sony é engraçada até ontem a quantidade de vendas do PS2 era de 155 milhões de unidades aí com o switch se aproximando eles vão lá e inventam que venderam 160 milhões 🤣
# 8. Se subir o preço dos jogos tbm, vou de Mig Switch forte para essa geração!
# 9. No lugar do Xbox Series X temos Nintendo Switch 2!
# 10. Metal gear Delta?<br>Pronto, agora eu já decidi qual vídeo game da nova geração comprar,vem switch 2!!!
#
# 🔹 **Exemplos do Cluster 8:**
# 1. Se pode fazer de mouse, pode ser uma excelente opção de FPS em console, não sei
# 2. Um mouse já no controle, se funcionar bem, será um bom pluss
# 3. Se lançou o mouse precisa lançar o teclado também hehe
# 4. nao gostei do mouse, eu jogo na cama como vou usar kkk ou no sofa, nunca joguei nintendo sentando na secretaria hhaha
# 5. Eu espero que tenha outras utilidades além do mouse, pois pra mim é meio indiferente já que não curto tanto os gêneros que se beneficiam do mouse.
# 6. Essa ideia de usar o joycon como mouse seria péssimo, o controle é fino, seria desconfortável utilizar desse modo, o Nintendo Switch já deveria ser compatível com teclado e mouse como é no PlayStation e Xbox.<br><br>Única coisa que me vem em mente de usar o controle como mouse, é que aí vão poder colocar Mario Paint no emulador de SNES, talvez quem sabe, vão fazer uma nova versão do Mario Paint, o que não seria uma má ideia.
# 7. <a href="https://www.youtube.com/watch?v=31BvwbyZG-4&amp;t=345">5:45</a> então se eu tiver dois pares de controles, posso conectar os dois lados direitos no mesmo console..... Finalmente um console pensado pra quem é ambidestro.
# 8. Só eu que acho que esse sistema de joycon vai estragar mais rápido que o antigo me preocupa esse mini pen-drive do lado mal ajustado pode quebrar dentro do equipamento?<br>Não via problema na questão de ter o trilho
# 9. Esse pro controler dividido 2 vira basicamente um desses comfort grip que vende atualmente.<br><br>Incrível. Sempre me perguntei porque a pro controller não se dividia igual um Joy Con.
# 10. Com toda certeza tera acessório pro Joycon ficar mais parecido com mouse
#
# 🔹 **Exemplos do Cluster 9:**
# 1. Coelhão, quando vai ser o encontro com o pessoal que comprou o Livro Projeto Nitendistas? Tava falando que ia ser fevereiro.
# 2. Já dei o like na versão em ingles e agora o like aqui. PH WE TRUST!
# 3. <a href="https://www.youtube.com/watch?v=AEvCxY_7mFk&amp;t=250">4:10</a> kkkk
# 4. Pra que maior?!?!?! O Cartuchinho é tão pequeno, até pra caixa atual dele 💀💀 e nem vem nada dentro dessas mídias físicas! Nem uma revistinha, brinde nem nada! Não faz sentido
# 5. Mudou da água pro Water 😂😂😂
# 6. <a href="https://www.youtube.com/watch?v=oWCscYgvdMo&amp;t=368">6:08</a> KKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK AH NÃO MANO, O ORGULHO QUE ELE DEMONSTRA NESSA PIADA FOI FANTÁSTICO.
# 7. E assim nasce um sucesso em vendas.
# 8. Cheguei com o like!
# 9. Pra mim o joy con parece pequeno ainda, poderia ser mais largo.
# 10. Uma parte dessas vendas com certeza graças a Jack Sparrow. 🌗☠️
#
# 🔹 **Exemplos do Cluster 10:**
# 1. Eu quero é um sistema melhor de metrica de jogos, quanto tempo a gente joga e mais estatísticas, o sistema do 3ds era tão bom
# 2. Se o meu S1 Oled puder juntar ao S2 e virar um megazord, seria tudo de bom.
# 3. Senhor linguiça desculpa perguntar isso, mas existe cabo melhor que o Ld 39 para conectar do celular para tv ? Se sim, qual ? Tô querendo jogar emulador
# 4. <a href="https://www.youtube.com/watch?v=rAPjNqGFgQk&amp;t=45">00:45</a> eu tenho um controle edição especial do splatoon que está dando esse problema.<br>Se eu mandar pra eles arrumarem vai voltar o mesmo controle ou eles apenas substituem ?😅
# 5. Segunda vez que mando meus joy cons pra deal, a primeira foi em 2021 (sim o drift é extremamente constante, ele sempre virá 😢) to esperando a entrega dos novos
# 6. sera que vai dar pra jogar PalWord ?
# 7. Meu sonho é a interface ser interativa e estilizada igual do 3DS, com menu intuitivo, modelos 3d para o icone dos jogos, com uma e-shop com musiquinha😭😭
# 8. <a href="https://www.youtube.com/watch?v=CluqxxjdXe8&amp;t=180">3:00</a> &quot;que o console tenha o problema de drift...😮😮... resolvido&quot; ata
# 9. Switch é uma mina de ouro. Reinventar a roda é algo que a Big N sempre fez mas arriscar um jogo ganho desse seria de uma burrice extrema.
# 10. Acho que jogos menores serão lançados para os dois
#
# 🔹 **Exemplos do Cluster 11:**
# 1. O cartucho é tão pequeno. Pra que uma caixa maior, devia ser algo pequeno igual a caixa do 3ds ou menor ainda
# 2. Pra mim o sw2 deveria aumetar o seu poder grafico quando colocado na dock
# 3. A série 30 da rtx é subutilizada em detrimento do lancamento da série 40 e 50 que virá. Mas ela tem potencial pra rodar dlss 3 como alguns hackers ja fizeram.<br>Com o polimento da nintendo não será estranho se ele rodar todos os jogos next gen dockado.<br>Com a retrocompatibilidade nao vejo a hora de rodar os classicos do switch com o upscaling nativo do S2
# 4. Só fico pé atrás pq todos os rumores levam em conta o desempenho máximo do chip, a chance dele ser capado é grande, lembra que o tegra x1 do switch tem 1tflop e foi capado pra menos da metade.
# 5. Vai rodar Crysis no máximo? 😅
# 6. Switch rodava 1080p uma grande quantidade de jogos 😅<br><br>Nier Automata por exemplo roda a 1080p no switch e  no ps4 roda a 900p.<br><br>Reduziram algumas texturas escondidas e fixaram o FPS em 30.<br><br>Isso na Dock.
# 7. Fico imaginando os exclusivos da BigN com todo este poder a disposição dos desenvolvedores vai ser FENOMENAL
# 8. hogwarts legacy tem pra geração passada tbm e detalhe que roda muito melhor que no switch.
# 9. É aquilo, tendo velocidade de leitura, memória ram e tecnologia recebte o Switch vai chegar forte ao mercado!
# 10. Ao que compreendi, até o momento, é que teremos duas saídas USB-C, uma abaixo e outra acima próxima do cartucho, serão 256gb de memória interna, HDMI 2.1 (4K compatible), teremos duas bands de memória LPDDR5X de 6gb (Ao lado do SoC da Nvidia) e que, supostamente, não são 8 nm e sim 5 nm, o que vai auxiliar com a questão de uso de energia desse sistema mais robusto quando usarmos como portátil. Até porque em docked mode o consumo de bateria é irrelevante. De qualquer maneira, é um pulo considerável e, provavelmente, a maneira correta de fazer um portátil que de quebra ainda é híbrido. Veremos.
#
# 🔹 **Exemplos do Cluster 12:**
# 1. Rdr2 é obrigação no switch!<br><br>GTA VI, se vier é lucro
# 2. Galera eu tenho o switch e vou comprar o 2 no lançamento, mais sei que o gta6 não vem para o game da Nintendo, principalmente depois que mostraram o design do Nswitch2
# 3. Para mim já está confirmado red dead 2 no switch 2 😊
# 4. Com o sucesso do Switch, GTA 6 ser lançado pro Switch 2 não é mais uma questão de se, mas sim quando.
# 5. GTA 5 Nintendo switch
# 6. Se conseguir rodar gta 6 vai ser absurdo, podera rodar quase qualquer jogo, e imagina oque não venderia, se tiver capacidade a rockstar vai querer trazer, seria 30 milhões de vendas garantidas
# 7. Não faz sentido GTA 6 pro switch 2 sendo que as pessoas estão com a dúvida se vai rodar bem no PS5.. pensem nisso.
# 8. Jogos da Rockstar da geração Ps4 sim, GTA 6 não vem nunca. Eu aposto caro como não vai vir. Só vão lançar jogos que são possíveis pro console.
# 9. GTA 6 levando em conta as especificações comparáveis ao XBOX SERIE S , não acredito que seja lançado para Nintendo switch 2.<br>E para lançar capado ou com donwgrade como foi mortal kombat 1 , não vai rolar mesmo.
# 10. GTA 6 sem chance, o 5 sim é possível.
#
# 🔹 **Exemplos do Cluster 13:**
# 1. O produto: 300 dólares<br>O br:certo entao, 10 mil reais.
# 2. Se esse preço for real eles tão de sacanagem
# 3. No Brasil a conversão é simples. Só  acrescentar um 0<br>Se sair por U$399 nos Estados Unidos, sai sai por R$3990<br>O que penso é se terá uma importação nacional como o Switch atual. O que pode ajudar a reduzir um pouco o preço por conta da quantidade <br>Mas se vier importado de forma independente… não vai ter mágica <br>Dólar acima de R$6, impostos pra caramba…
# 4. Não duvido que venha por 400 usd e por volta de 3500 reais, mas o problema pra mim são os jogos, tivemos recentemente os jogos vindo com aumento mais uma vez, mídia física 350 reais, localização de preço não é conversão, isso é fora da realidade do Brasil, eu já perdi o hype de pegar o Switch 2 no lançamento por conta disso, essa politica de preço dos jogos por aqui me trás uma perspectiva muito ruim.
# 5. Eu sempre digo, o vídeo game sempre foi barato, a conversão é que faz ele se tornar caro. <br>Pagar 10 x o valor é caro em qualquer lugar do mundo, qualquer classe média nos E.U.A ou Europa compra em um mês tranquilo.<br>Mais a sua análise é real, não tem como custar menos.
# 6. Eu chuto 399 dólares lá nos EUA. Os jogos digitais no Brasil vai ficar em 349 reais e os jogos físicos 399 reais.
# 7. Bom dia Fiaspo! Acredito que o preço será como voce mencionou, creio que só vai chegar na mão do brasileiro no meio do ano. O que me diz ?
# 8. Vai custar no Br cerca de 4500 reais. É daí pra cima, galera.
# 9. Preciso convencer minha muie😅. Aqui no Japão vai ser mais acessível, tomara.
# 10. Eu acho que esse preço é fake. Tá escrito &quot;Palce&quot; holder &#39;-&#39;
#
# 🔹 **Exemplos do Cluster 14:**
# 1. Não tem como dar um time skip para dois de abril não? Se bem que ai perco a pokemon direct😂
# 2. Lançamento em meados de maio, pode anotar
# 3. Era bem isso que pensei dig todo fevereiro sempre teve direct agora ficaremos as escuras provavelmente o foco sera a next gen mesmo
# 4. Acho que não faria sentido msmo uma direct agora em fevereiro com outra anunciada pra abril
# 5. Pode ser que saia em abril mesmo ou maio. O console já está em produção.<br><br>Lançando em junho pegam o verão no hemisfério norte.
# 6. O evento de fevereiro deve ser uma direct mini ou uma indie world Dig!
# 7. Ai boom, a data de lançamento vai ser uma semana depois da direct.
# 8. o vídeo tinha 2 minutos e 22 segundos. acho que isso pode ser uma dica sobre data de lançamento ou outra coisa
# 9. Não sei de onde vocês tiraram que ia ter direct esse mês de fevereiro. Se vai ter direct em abril. Pra quê ter uma em fevereiro?? Se não tivesse em abril, aí tudo bem!!
# 10. Esse mês teremos somente a Pokémon direct dia 27.

# %%
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt


tsne = TSNE(n_components=2, random_state=42)
embeddings_2d = tsne.fit_transform(embeddings)

df_viz = pd.DataFrame({"x": embeddings_2d[:, 0], "y": embeddings_2d[:, 1], "cluster": labels})
plt.figure(figsize=(8, 6))
sns.scatterplot(x="x", y="y", hue="cluster", data=df_viz, palette="tab10")
plt.title("Visualização dos Clusters com t-SNE")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# Ajustar PCA nos embeddings
pca = PCA()
pca.fit(embeddings)

# Variância explicada acumulada
explained_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# Plotar o gráfico da variância explicada
plt.figure(figsize=(6,4))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='--')
plt.xlabel("Número de Componentes Principais")
plt.ylabel("Variância Explicada Acumulada")
plt.title("Escolha do Número de Componentes no PCA")
plt.axhline(y=0.95, color='r', linestyle='--', label='95% de variância explicada')
plt.legend()
plt.show()

# %%
num_components = 40  # Escolha com base no gráfico

pca = PCA(n_components=num_components)
embeddings_pca = pca.fit_transform(embeddings)

# %%
ks = range(1, 15)
inertias = []

for k in ks:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(embeddings_pca)
    inertias.append(kmeans.inertia_)

# Plotar o método do cotovelo
plt.figure(figsize=(6,4))
plt.plot(ks, inertias, marker='o', linestyle='--')
plt.xlabel("Número de Clusters (K)")
plt.ylabel("Inércia (Soma das Distâncias)")
plt.title("Método do Cotovelo para Escolha do K")
plt.show()

# %%
import faiss
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# 🔹 Reduzir a dimensionalidade com PCA para analisar o número ideal de clusters
def calcular_k_pca(embeddings, variancia_min=0.95):
    pca = PCA().fit(embeddings)
    variancia_acumulada = np.cumsum(pca.explained_variance_ratio_)

    # Encontrar o número mínimo de componentes que explicam pelo menos 95% da variância
    k_pca = np.argmax(variancia_acumulada >= variancia_min) + 1

    # Aplicar a transformação PCA para reduzir dimensionalidade
    pca_embeddings = PCA(n_components=k_pca).fit_transform(embeddings)

    # Plotando a variância explicada
    plt.figure(figsize=(8,5))
    plt.plot(variancia_acumulada, marker="o")
    plt.axhline(y=variancia_min, color='r', linestyle="--", label=f"{variancia_min*100:.0f}% de variância explicada")
    plt.xlabel("Número de Componentes Principais")
    plt.ylabel("Variância Explicada Acumulada")
    plt.title("Escolha do Número de Componentes no PCA")
    plt.legend()
    plt.show()

    print(f"🔹 Número de componentes sugerido pelo PCA: {k_pca}")
    return k_pca, pca_embeddings  # Retorna também os embeddings reduzidos

# 🔹 Método do cotovelo para escolha numérica do K
def encontrar_melhor_k(embeddings, k_min=2, k_max=15):
    inercia = []
    ks = list(range(k_min, k_max + 1))

    for k in ks:
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        kmeans.fit(embeddings)
        inercia.append(kmeans.inertia_)

    # Diferença de inclinação entre pontos consecutivos
    variacoes = np.diff(inercia)

    # Definição do ponto do "cotovelo"
    melhor_k = ks[np.argmin(variacoes[:k_max-2]) + 1]

    # Plotar a curva de inércia
    plt.figure(figsize=(8,5))
    plt.plot(ks, inercia, marker="o", linestyle="--")
    plt.axvline(melhor_k, color="r", linestyle="--", label=f"K escolhido = {melhor_k}")
    plt.xlabel("Número de Clusters (K)")
    plt.ylabel("Inércia (Soma das Distâncias)")
    plt.title("Método do Cotovelo para Escolha do K")
    plt.legend()
    plt.show()

    print(f"🔹 Melhor número de clusters encontrado: {melhor_k}")
    return melhor_k

# 🔹 Função para rodar FAISS com o K-Means
def rodar_kmeans_faiss(embeddings, k):
    print(f"\n🚀 Rodando K-Means com FAISS para K = {k}")
    
    # Definir FAISS KMeans
    kmeans = faiss.Kmeans(d=embeddings.shape[1], k=k, niter=300, nredo=10, spherical=True)
    kmeans.train(embeddings)

    # Atribuir clusters
    _, labels = kmeans.index.search(embeddings, 1)
    labels = labels.flatten()

    return labels

# 🔹 Função para exibir exemplos de cada cluster
def mostrar_exemplos_clusters(textos_originais, labels):
    df = pd.DataFrame({"text": textos_originais, "cluster": labels})

    for cluster_id in sorted(df["cluster"].unique()):
        print(f"\n🔹 **Exemplos do Cluster {cluster_id}:**")
        exemplos = df[df["cluster"] == cluster_id]["text"]
        if exemplos.shape[0] < 10:
            exemplos = exemplos.sample(exemplos.shape[0], random_state=42)  # Evita erro se houver poucos exemplos
        else:
            exemplos = exemplos.sample(10, random_state=42)  # Pegando 10 exemplos
        
        for idx, texto in enumerate(exemplos, start=1):
            print(f"{idx}. {texto}")

# 🔹 Pipeline de Clustering
def pipeline_clustering(embeddings, textos_originais):
    # Passo 1: Determinar K pelo PCA e reduzir dimensionalidade
    k_pca, pca_embeddings = calcular_k_pca(embeddings)

    # Passo 2: Determinar K pelo cotovelo usando os embeddings reduzidos
    k_elbow = encontrar_melhor_k(pca_embeddings)  # Usando pca_embeddings aqui

    k_final = k_elbow 

    print(f"\n🔹 Testando FAISS K-Means com K = {k_final}")

    # Rodar K-Means com FAISS nos embeddings reduzidos
    labels = rodar_kmeans_faiss(pca_embeddings, k_final)

    # Mostrar exemplos dos clusters
    mostrar_exemplos_clusters(textos_originais, labels)

# 🔹 Verifica se os embeddings estão disponíveis
if 'embeddings' not in locals():
    raise ValueError("❌ ERRO: A variável `embeddings` não foi definida. Carregue os embeddings antes de rodar.")

if 'textos_originais' not in locals():
    raise ValueError("❌ ERRO: A variável `textos_originais` não foi definida.")

# 🚀 Rodar o pipeline de clustering
pipeline_clustering(embeddings, textos_originais)
# Out:
# 🔹 Número de componentes sugerido pelo PCA: 484
# 🔹 Melhor número de clusters encontrado: 3
#
# 🔹 Testando FAISS K-Means com K = 3
#
# 🚀 Rodando K-Means com FAISS para K = 3
#
# 🔹 **Exemplos do Cluster 0:**
# 1. Sou Nintendista e odeiop Apple.
# 2. pra jogar pokemon, mario e zelda vai dar pra jogar lisinho, então fod*** os jogos multi, quer jogar jogo  multi é ps5 pro e PC
# 3. Esse mouse fica perfeito com Mario Maker 3 kkkkk
# 4. Gaveta gosto muito quando você faz vídeos sobre videogames. Pode ser + 1 tópico do canal.
# 5. Excelente vídeo. Só uma correção: Nintendinho só tem botões A e B. Foi o Super Nintendo que trouxe o X e Y (além do R e L).
# 6. tenho certeza que a nintendo vai lançar seu mouse!
# 7. PH as bgm de Splatoon significam mais conteúdo pro Splatoon 3 ou Splatoon 4 nesse ano? Pisca uma vez pra primeira e duas pra segunda.
# 8. Agora eu compro meu super Nintendo baby 😌
# 9. Coelho dizendo que não gosta de spoiler e gosta de ser surpreendido: 😔<br><br>Coelho também ao menor sinal de qualquer coisa sobre novo console na internet: 🗣️
# 10. Caraca, vc me ajudou a zerar Zelda BotW no lancamento. Tmj man.
#
# 🔹 **Exemplos do Cluster 1:**
# 1. Adriano ta tenebroso na thumb kkkkk
# 2. Foi muito bem Ph, o torna forte é oq ele é capaz de rodar e não tflops que é só no papel
# 3. aqui no BR é sempre assim, pega o preço em dólar e multiplica por 10
# 4. É muito forte. Uma vez eu vi o Switch 2 levando as compras do mês do carro pra dentro de casa em uma viagem só, carregando todas as sacolas em uma só mão.
# 5. A música de FFVII Remake no final 😍
# 6. Na imagem o controle tem o formato de um rato com calda e tudo só prestar atenção que dá pra ver 😮
# 7. Muito bom Display! Se for uma 3050 roda tudo hoje no mercado no mínimo a 1080P e configurações altas.
# 8. Áudio gravado direto da geladeira do PH
# 9. O Monstro está Saindo da Jaula.
# 10. não tem criador de conteudo melhor que o damiani, desde 2014 me tirando otimas rizadas, muito bom te ver por aqui novamente, por favor, reposta o seu cover da abertura de Chobits
#
# 🔹 **Exemplos do Cluster 2:**
# 1. Switch destravado é uma das maiores maravilhas que existe, da pra encontrar desbloqueado por ate 1500, considerando que não precisa ter nenhum gasto depois da compra é absurdo
# 2. Nintendo Switch 1 é a prova viva que o PS4 poderia ter recebido Mortal Kombat 1
# 3. Poderia criar um conteúdo citando acessórios e jogos para quem já tem o Switch a bastante tempo e ainda vale a pena comprar esse ano mesmo após o lançamento do Switch 2. Exemplo cases para manter ele guardado ou na prateleira
# 4. Pelo que eu vi esse switch vai continuar não sendo o console mais poderoso nem de longe, mas já vai dar uma boa margem para Port dos jogos de ps4 e xbox one.
# 5. Se o S2 fizer, comparado ao PS4, o que o Switch faz coparado ao PS3 estou traquilo. Só espero que eles não cobrem  valor de um PS5. E eu pagaria até valor de DLC se pelo menos os exclusivos do S1 ganhassem pacotes gráficos e otimizações que aproveitem o novo hardware. Nããã...Eles vão fazer isso e vender full price...
# 6. Só um adendo: a funcionalidade de mouse abre um leque maior de possibilidades como no uso para jogos em primeira pessoa, ou, quem sabe, um modo desktop.
# 7. Ótimo vídeo Velberan parabéns ae amigo, que massa hein o assunto essa regra dos 2 anos é bem real mesmo pq sempre os primeiros modelos dão ruim hein, a pessoa tem que ver o que vale mais a pena pra ela esperar e comprar um Switch mais barato até esses 2 anos ou comprar no lançamento se ela tiver condições ou for rica vai de cada um mesmo.
# 8. Uma coisa que fico pensando, como o Switch 2 vai chegar a 400 dólares, se o Switch Oled está 350 dólares, 50 dólares para tantas melhorias, sei lá. Como está sendo falado por ai, ele deve ter o poder equivalente ao do Xbox Series S, portátil ainda (geralmente portátil é mais caro). Soma-se a isso, o fato da Nintendo não subsidiar console, diferente das concorrentes. Para mim não chega menos de 450 dólares, e não chega a mais de 550 dólares...
# 9. De acordo com o q foi estudado sobre o vazamento no modo portátil el tera 2 teraflops de potência um pouco superior ao Ps4 normal e na doca 3,6 quase um Ps4 pro, terá Ray-tracing, usaria placa invídia da série e rtx20 terá núcleos dedicados pra inteligência artificial q vai tbm otimizar os gráficos,12 gb de ram ddrs,  eu não sei os detalhes de tudo isso então eu recomendaria o short do canal Autoridade Tech onde ele fala as especificações mais direto ao ponto
# 10. Metal gear Delta?<br>Pronto, agora eu já decidi qual vídeo game da nova geração comprar,vem switch 2!!!

# %%
from sklearn.mixture import GaussianMixture
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE

# Encontrar o número ideal de clusters usando BIC
bic_scores = []
k_values = range(2, 11)  # Testamos de 2 a 10 clusters

for k in k_values:
    gmm = GaussianMixture(n_components=k, covariance_type='full', random_state=42)
    gmm.fit(embeddings)
    bic_scores.append(gmm.bic(embeddings))  # Salvar o BIC

# Definir o melhor número de clusters (menor BIC)
best_k = k_values[np.argmin(bic_scores)]
print(f"Número ideal de clusters: {best_k}")

# Treinar o modelo GMM com o melhor k
gmm = GaussianMixture(n_components=best_k, covariance_type='full', random_state=42)
clusters = gmm.fit_predict(embeddings)

# Reduzir dimensionalidade para 2D com t-SNE para visualização
tsne = TSNE(n_components=2, random_state=42)
embeddings_2d = tsne.fit_transform(embeddings)

# Criar DataFrame para visualização
import pandas as pd
df_viz = pd.DataFrame({
    "x": embeddings_2d[:, 0],
    "y": embeddings_2d[:, 1],
    "cluster": clusters
})

# Plot dos clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(x="x", y="y", hue="cluster", data=df_viz, palette="tab10")
plt.title("Clusters identificados com GMM")
plt.show()
# Out:
# Número ideal de clusters: 2

# %%
import umap
import hdbscan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Reduzir dimensionalidade com UMAP (de embeddings originais para 2D)
umap_reducer = umap.UMAP(n_components=20, random_state=42)
embeddings_2d = umap_reducer.fit_transform(embeddings)

# Rodar HDBSCAN para encontrar clusters automaticamente
hdbscan_cluster = hdbscan.HDBSCAN(min_cluster_size=10, min_samples=3, cluster_selection_method='eom')
clusters = hdbscan_cluster.fit_predict(embeddings)

# Criar DataFrame para visualização
df_viz = pd.DataFrame({
    "x": embeddings_2d[:, 0],
    "y": embeddings_2d[:, 1],
    "cluster": clusters
})

# Plot dos clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(x="x", y="y", hue="cluster", data=df_viz, palette="tab10")
plt.title("Clusters identificados com UMAP + HDBSCAN")
plt.show()

# Mostrar quantos clusters foram detectados
num_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)  # "-1" são pontos considerados ruído
print(f"Número de clusters detectados: {num_clusters}")
# Out:
# C:\Users\Victor\.conda\envs\fiap_tech2\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# C:\Users\Victor\.conda\envs\fiap_tech2\Lib\site-packages\umap\umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#
# C:\Users\Victor\.conda\envs\fiap_tech2\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# C:\Users\Victor\.conda\envs\fiap_tech2\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Número de clusters detectados: 2
